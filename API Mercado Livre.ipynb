# %% [markdown]
# ### Mercado Livre
# Vamos utilizar a API do MercadoLivre para consultar anúncios<br>
# <strong>O que fazer</strong>: acesso, download, tratamento e cálculo<br>
# <strong>Documentação</strong>: https://developers.mercadolivre.com.br/pt_br/api-docs-pt-br<br>
# <strong>Objetivo</strong>: Qual o preço médio dos anúncios de iphones em Minas Gerais<br>
# <strong>Desafio</strong>: Resolve o exercício através de uma função para permitir realizar a mesma consulta com outros itens ou estados<br>
# <strong>Dica</strong>: Carregue seus dados para um dataframe para facilitar a manipulação dos dados

# %%
import sys
import json
import codecs
import urllib.request
import urllib.parse
import pandas as pd
import requests

def usage():
    print('Uso: {0} "PRODUTO"'.format(sys.argv[0]))
    print('Busque um produto por vez')
    sys.exit(1)
    
def busca(item):
    url = 'https://api.mercadolibre.com/sites/MLB/search?q={0}'.format(item)
    opener = urllib.request.build_opener()
    opener.addheaders = [
        ('User-agent',
         "Mozilla/5.0 (Windows; U; Windows NT 6.1; rv:2.2) Gecko/20110201")]

    with opener.open(url) as fd:
        content = fd.read()
        encoding = fd.info().get_content_charset()
        content = content.decode(encoding)

    dic = json.loads(content)
    #utf-8

# encoding
# 0001 = 'A' (encoding 1)
# 0001 = '$' (encoding 2)

    
    return dic

# %%
temp = requests.get('https://api.mercadolibre.com/sites/MLB/search?q=iphone')

# %%
temp.json()
# Out:
# {'site_id': 'MLB',
#  'query': 'iphone',
#  'paging': {'total': 37596, 'primary_results': 1000, 'offset': 0, 'limit': 50},
#  'results': [{'id': 'MLB1729453817',
#    'site_id': 'MLB',
#    'title': 'Apple iPhone 11 (128 Gb) - Branco',
#    'seller': {'id': 234000251,
#     'permalink': 'http://perfil.mercadolivre.com.br/FASTSHOP+OFICIAL',
#     'registration_date': '2016-11-09T09:05:35.000-04:00',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': ['brand',
#      'large_seller',
#      'mshops',
#      'messages_as_seller',
#      'messages_as_buyer'],
#     'seller_reputation': {'transactions': {'total': 164024,
#       'canceled': 10534,
#       'period': 'historic',
#       'ratings': {'negative': 0.02, 'positive': 0.94, 'neutral': 0.04},
#       'completed': 153490},
#      'power_seller_status': None,
#      'metrics': {'claims': {'rate': 0.0114, 'value': 178, 'period': '60 days'},
#       'delayed_handling_time': {'rate': 0.1214,
#        'value': 511,
#        'period': '60 days'},
#       'sales': {'period': '60 days', 'completed': 14492},
#       'cancellations': {'rate': 0.0254, 'value': 394, 'period': '60 days'}},
#      'level_id': '5_green'}},
#    'price': 4454,
#    'prices': {'id': 'MLB1729453817',
#     'prices': [{'id': '55',
#       'type': 'standard',
#       'conditions': {'context_restrictions': [],
#        'start_time': None,
#        'end_time': None,
#        'eligible': True},
#       'amount': 4499,
#       'regular_amount': None,
#       'currency_id': 'BRL',
#       'exchange_rate_context': 'DEFAULT',
#       'metadata': {},
#       'last_updated': '2021-06-23T12:52:06Z'},
#      {'id': '61',
#       'type': 'promotion',
#       'conditions': {'context_restrictions': [],
#        'start_time': '2021-06-25T03:00:00Z',
#        'end_time': '2021-06-26T02:59:59Z',
#        'eligible': True},
#       'amount': 4454,
#       'regular_amount': 5599,
#       'currency_id': 'BRL',
#       'exchange_rate_context': 'DEFAULT',
#       'metadata': {'promotion_id': '11034819-MLB1729453817',
#        'promotion_type': 'deal_of_the_day'},
#       'last_updated': '2021-06-24T22:00:05Z'}],
#     'presentation': {'display_currency': 'BRL'},
#     'payment_method_prices': [],
#     'reference_prices': [],
#     'purchase_discounts': []},
#    'sale_price': None,
#    'currency_id': 'BRL',
#    'available_quantity': 882,
#    'sold_quantity': 1713,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2040-11-22T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://www.mercadolivre.com.br/apple-iphone-11-128-gb-branco/p/MLB15149568',
#    'thumbnail': 'http://http2.mlstatic.com/D_821379-MLA46114620180_052021-I.jpg',
#    'thumbnail_id': '821379-MLA46114620180_052021',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 371.17,
#     'rate': 0,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-SP',
#     'state_name': 'São Paulo',
#     'city_id': 'QlItU1BDYWphbWFy',
#     'city_name': 'Cajamar'},
#    'shipping': {'free_shipping': False,
#     'mode': 'me1',
#     'tags': [],
#     'logistic_type': 'default',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-SP', 'name': 'São Paulo'},
#     'city': {'id': 'QlItU1BDYWphbWFy', 'name': 'Cajamar'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'values': [{'id': '9344',
#        'name': 'Apple',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'id': 'BRAND',
#      'value_struct': None,
#      'value_name': 'Apple',
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'name': 'Marca',
#      'value_id': '9344'},
#     {'value_id': '7740544',
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'attribute_group_id': 'OTHERS',
#      'id': 'GPU_MODEL',
#      'name': 'Modelo de GPU',
#      'value_name': 'Apple GPU MP4',
#      'value_struct': None,
#      'values': [{'source': 1,
#        'id': '7740544',
#        'name': 'Apple GPU MP4',
#        'struct': None}]},
#     {'attribute_group_id': 'OTHERS',
#      'name': 'Condição do item',
#      'value_id': '2230284',
#      'value_struct': None,
#      'values': [{'source': 1,
#        'id': '2230284',
#        'name': 'Novo',
#        'struct': None}],
#      'id': 'ITEM_CONDITION',
#      'value_name': 'Novo',
#      'attribute_group_name': 'Outros',
#      'source': 1},
#     {'value_name': 'iPhone',
#      'value_struct': None,
#      'source': 1,
#      'id': 'LINE',
#      'name': 'Linha',
#      'value_id': '58993',
#      'values': [{'struct': None,
#        'source': 1,
#        'id': '58993',
#        'name': 'iPhone'}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros'},
#     {'name': 'Modelo',
#      'value_id': '7739079',
#      'value_struct': None,
#      'values': [{'id': '7739079',
#        'name': 'iPhone 11',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'id': 'MODEL',
#      'value_name': 'iPhone 11',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros'},
#     {'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'name': 'Modelo do processador',
#      'value_id': '7740540',
#      'value_struct': None,
#      'source': 1,
#      'id': 'PROCESSOR_MODEL',
#      'value_name': 'Apple A13 Bionic',
#      'values': [{'id': '7740540',
#        'name': 'Apple A13 Bionic',
#        'struct': None,
#        'source': 1}]},
#     {'value_struct': {'number': 194, 'unit': 'g'},
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'id': 'WEIGHT',
#      'name': 'Peso',
#      'value_id': '2583040',
#      'value_name': '194 g',
#      'values': [{'name': '194 g',
#        'struct': {'number': 194, 'unit': 'g'},
#        'source': 1,
#        'id': '2583040'}]}],
#    'differential_pricing': {'id': 33580182},
#    'original_price': 5599,
#    'category_id': 'MLB1055',
#    'official_store_id': 942,
#    'domain_id': 'MLB-CELLPHONES',
#    'catalog_product_id': 'MLB15149568',
#    'tags': ['deal_of_the_day',
#     'good_quality_picture',
#     'good_quality_thumbnail',
#     'brand_verified',
#     'immediate_payment',
#     'cart_eligible',
#     'shipping_guaranteed',
#     'meli_choice_candidate'],
#    'catalog_listing': True,
#    'use_thumbnail_id': True,
#    'order_backend': 1},
#   {'id': 'MLB1929087758',
#    'site_id': 'MLB',
#    'title': 'Apple iPhone 11 (64 Gb) - Preto',
#    'seller': {'id': 53046290,
#     'permalink': 'http://perfil.mercadolivre.com.br/ABESHOPS',
#     'registration_date': '2008-08-04T23:49:18.000-04:00',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': ['normal',
#      'mshops',
#      'credits_profile',
#      'messages_as_seller',
#      'messages_as_buyer'],
#     'seller_reputation': {'transactions': {'total': 38,
#       'canceled': 2,
#       'period': 'historic',
#       'ratings': {'negative': 0, 'positive': 1, 'neutral': 0},
#       'completed': 36},
#      'power_seller_status': None,
#      'metrics': {'claims': {'rate': 0, 'value': 1, 'period': '365 days'},
#       'delayed_handling_time': {'rate': 0, 'value': 0, 'period': '365 days'},
#       'sales': {'period': '365 days', 'completed': 36},
#       'cancellations': {'rate': 0, 'value': 0, 'period': '365 days'}},
#      'level_id': '5_green'}},
#    'price': 4439,
#    'prices': {'id': 'MLB1929087758',
#     'prices': [{'id': '2',
#       'type': 'standard',
#       'conditions': {'context_restrictions': [],
#        'start_time': None,
#        'end_time': None,
#        'eligible': True},
#       'amount': 4439,
#       'regular_amount': None,
#       'currency_id': 'BRL',
#       'exchange_rate_context': 'DEFAULT',
#       'metadata': {},
#       'last_updated': '2021-06-25T21:50:46Z'}],
#     'presentation': {'display_currency': 'BRL'},
#     'payment_method_prices': [],
#     'reference_prices': [],
#     'purchase_discounts': []},
#    'sale_price': None,
#    'currency_id': 'BRL',
#    'available_quantity': 1,
#    'sold_quantity': 0,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2041-06-20T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://www.mercadolivre.com.br/apple-iphone-11-64-gb-preto/p/MLB15149561',
#    'thumbnail': 'http://http2.mlstatic.com/D_832687-MLA46114578406_052021-I.jpg',
#    'thumbnail_id': '832687-MLA46114578406_052021',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 369.92,
#     'rate': 0,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-SP',
#     'state_name': 'São Paulo',
#     'city_id': 'BR-SP-44',
#     'city_name': 'São Paulo'},
#    'shipping': {'free_shipping': True,
#     'mode': 'me2',
#     'tags': ['mandatory_free_shipping'],
#     'logistic_type': 'drop_off',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-SP', 'name': 'São Paulo'},
#     'city': {'id': 'BR-SP-44', 'name': 'São Paulo'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'name': 'Marca',
#      'source': 1,
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'id': 'BRAND',
#      'value_id': '9344',
#      'value_name': 'Apple',
#      'value_struct': None,
#      'values': [{'id': '9344', 'name': 'Apple', 'struct': None, 'source': 1}]},
#     {'value_name': 'Apple GPU MP4',
#      'values': [{'id': '7740544',
#        'name': 'Apple GPU MP4',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'id': 'GPU_MODEL',
#      'name': 'Modelo de GPU',
#      'value_id': '7740544',
#      'value_struct': None,
#      'source': 1},
#     {'id': 'ITEM_CONDITION',
#      'value_name': 'Novo',
#      'attribute_group_name': 'Outros',
#      'name': 'Condição do item',
#      'value_id': '2230284',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Novo',
#        'struct': None,
#        'source': 7092}],
#      'attribute_group_id': 'OTHERS',
#      'source': 7092},
#     {'name': 'Linha',
#      'value_id': '58993',
#      'value_name': 'iPhone',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'id': 'LINE',
#      'source': 1,
#      'values': [{'id': '58993',
#        'name': 'iPhone',
#        'struct': None,
#        'source': 1}]},
#     {'source': 1,
#      'id': 'MODEL',
#      'value_id': '7739079',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'name': 'Modelo',
#      'value_name': 'iPhone 11',
#      'value_struct': None,
#      'values': [{'id': '7739079',
#        'name': 'iPhone 11',
#        'struct': None,
#        'source': 1}]},
#     {'id': 'PROCESSOR_MODEL',
#      'values': [{'id': '7740540',
#        'name': 'Apple A13 Bionic',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'value_struct': None,
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'name': 'Modelo do processador',
#      'value_id': '7740540',
#      'value_name': 'Apple A13 Bionic'},
#     {'attribute_group_name': 'Outros',
#      'name': 'Peso',
#      'value_id': '2583040',
#      'values': [{'id': '2583040',
#        'name': '194 g',
#        'struct': {'unit': 'g', 'number': 194},
#        'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'source': 1,
#      'id': 'WEIGHT',
#      'value_name': '194 g',
#      'value_struct': {'number': 194, 'unit': 'g'}}],
#    'differential_pricing': {'id': 33580182},
#    'original_price': None,
#    'category_id': 'MLB1055',
#    'official_store_id': None,
#    'domain_id': 'MLB-CELLPHONES',
#    'catalog_product_id': 'MLB15149561',
#    'tags': ['extended_warranty_eligible',
#     'immediate_payment',
#     'cart_eligible',
#     'shipping_guaranteed'],
#    'catalog_listing': True,
#    'use_thumbnail_id': True,
#    'order_backend': 2},
#   {'id': 'MLB1859295006',
#    'site_id': 'MLB',
#    'title': ' iPhone 7 32 Gb Ouro Rosa',
#    'seller': {'id': 577525755,
#     'permalink': 'http://perfil.mercadolivre.com.br/ELIETE+SOLARIS',
#     'registration_date': '2020-08-08T09:30:53.000-04:00',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': ['normal',
#      'credits_profile',
#      'messages_as_seller',
#      'messages_as_buyer'],
#     'seller_reputation': {'transactions': {'total': 52,
#       'canceled': 8,
#       'period': 'historic',
#       'ratings': {'negative': 0, 'positive': 1, 'neutral': 0},
#       'completed': 44},
#      'power_seller_status': None,
#      'metrics': {'claims': {'rate': 0, 'value': 1, 'period': '365 days'},
#       'delayed_handling_time': {'rate': 0.0212,
#        'value': 1,
#        'period': '365 days'},
#       'sales': {'period': '365 days', 'completed': 44},
#       'cancellations': {'rate': 0, 'value': 1, 'period': '365 days'}},
#      'level_id': '5_green'}},
#    'price': 1525,
#    'prices': {'id': 'MLB1859295006',
#     'prices': [{'id': '9',
#       'type': 'standard',
#       'conditions': {'context_restrictions': [],
#        'start_time': None,
#        'end_time': None,
#        'eligible': True},
#       'amount': 1525,
#       'regular_amount': None,
#       'currency_id': 'BRL',
#       'exchange_rate_context': 'DEFAULT',
#       'metadata': {},
#       'last_updated': '2021-06-25T15:56:07Z'}],
#     'presentation': {'display_currency': 'BRL'},
#     'payment_method_prices': [],
#     'reference_prices': [],
#     'purchase_discounts': []},
#    'sale_price': None,
#    'currency_id': 'BRL',
#    'available_quantity': 1,
#    'sold_quantity': 2,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2041-04-13T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://www.mercadolivre.com.br/iphone-7-32-gb-ouro-rosa/p/MLB6240113',
#    'thumbnail': 'http://http2.mlstatic.com/D_665554-MLA43711395476_102020-I.jpg',
#    'thumbnail_id': '665554-MLA43711395476_102020',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 127.08,
#     'rate': 0,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-SP',
#     'state_name': 'São Paulo',
#     'city_id': 'QlItU1BDYXBpdmFyaQ',
#     'city_name': 'Capivari'},
#    'shipping': {'free_shipping': True,
#     'mode': 'me2',
#     'tags': ['mandatory_free_shipping'],
#     'logistic_type': 'drop_off',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-SP', 'name': 'São Paulo'},
#     'city': {'id': 'QlItU1BDYXBpdmFyaQ', 'name': 'Capivari'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'name': 'Marca',
#      'value_id': '9344',
#      'value_name': 'Apple',
#      'values': [{'struct': None, 'source': 1, 'id': '9344', 'name': 'Apple'}],
#      'id': 'BRAND',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 1},
#     {'id': 'GPU_MODEL',
#      'value_name': 'PowerVR Series7XT Plus',
#      'value_struct': None,
#      'values': [{'id': '8010379',
#        'name': 'PowerVR Series7XT Plus',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'name': 'Modelo de GPU',
#      'value_id': '8010379',
#      'attribute_group_id': 'OTHERS'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condição do item',
#      'value_id': '2230284',
#      'value_name': 'Novo',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 6808261514773724,
#      'values': [{'source': 6808261514773724,
#        'id': '2230284',
#        'name': 'Novo',
#        'struct': None}]},
#     {'values': [{'struct': None,
#        'source': 1,
#        'id': '58993',
#        'name': 'iPhone'}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'name': 'Linha',
#      'value_id': '58993',
#      'value_name': 'iPhone',
#      'id': 'LINE',
#      'value_struct': None,
#      'source': 1},
#     {'values': [{'id': '312155',
#        'name': 'iPhone 7',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'attribute_group_id': 'OTHERS',
#      'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': '312155',
#      'value_name': 'iPhone 7',
#      'value_struct': None},
#     {'attribute_group_id': 'OTHERS',
#      'name': 'Modelo do processador',
#      'value_id': '6946002',
#      'value_name': 'Apple A10 Fusion',
#      'value_struct': None,
#      'values': [{'id': '6946002',
#        'name': 'Apple A10 Fusion',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'id': 'PROCESSOR_MODEL'},
#     {'source': 1,
#      'name': 'Peso',
#      'value_name': '138 g',
#      'value_struct': {'number': 138, 'unit': 'g'},
#      'attribute_group_name': 'Outros',
#      'id': 'WEIGHT',
#      'value_id': '522902',
#      'values': [{'struct': {'unit': 'g', 'number': 138},
#        'source': 1,
#        'id': '522902',
#        'name': '138 g'}],
#      'attribute_group_id': 'OTHERS'}],
#    'differential_pricing': {'id': 33580182},
#    'original_price': None,
#    'category_id': 'MLB1055',
#    'official_store_id': None,
#    'domain_id': 'MLB-CELLPHONES',
#    'catalog_product_id': 'MLB6240113',
#    'tags': ['loyalty_discount_eligible',
#     'extended_warranty_eligible',
#     'good_quality_picture',
#     'immediate_payment',
#     'cart_eligible',
#     'meli_choice_candidate'],
#    'catalog_listing': True,
#    'use_thumbnail_id': True,
#    'order_backend': 3},
#   {'id': 'MLB1924083629',
#    'site_id': 'MLB',
#    'title': ' iPhone XR 64 Gb Branco',
#    'seller': {'id': 36583886,
#     'permalink': 'http://perfil.mercadolivre.com.br/UPFONE',
#     'registration_date': '2010-11-04T11:50:42.000-04:00',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': ['normal',
#      'credits_priority_3',
#      'credits_profile',
#      'messages_as_seller',
#      'messages_as_buyer'],
#     'seller_reputation': {'transactions': {'total': 5391,
#       'canceled': 507,
#       'period': 'historic',
#       'ratings': {'negative': 0.11, 'positive': 0.85, 'neutral': 0.04},
#       'completed': 4884},
#      'power_seller_status': 'platinum',
#      'metrics': {'claims': {'rate': 0.0157, 'value': 20, 'period': '60 days'},
#       'delayed_handling_time': {'rate': 0.0016,
#        'value': 2,
#        'period': '60 days'},
#       'sales': {'period': '60 days', 'completed': 1169},
#       'cancellations': {'rate': 0, 'value': 1, 'period': '60 days'}},
#      'level_id': '5_green'}},
#    'price': 3642,
#    'prices': {'id': 'MLB1924083629',
#     'prices': [{'id': '3',
#       'type': 'standard',
#       'conditions': {'context_restrictions': [],
#        'start_time': None,
#        'end_time': None,
#        'eligible': True},
#       'amount': 3642,
#       'regular_amount': None,
#       'currency_id': 'BRL',
#       'exchange_rate_context': 'DEFAULT',
#       'metadata': {},
#       'last_updated': '2021-06-23T22:04:47Z'}],
#     'presentation': {'display_currency': 'BRL'},
#     'payment_method_prices': [],
#     'reference_prices': [],
#     'purchase_discounts': []},
#    'sale_price': None,
#    'currency_id': 'BRL',
#    'available_quantity': 1,
#    'sold_quantity': 12,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2041-06-16T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://www.mercadolivre.com.br/iphone-xr-64-gb-branco/p/MLB12866679',
#    'thumbnail': 'http://http2.mlstatic.com/D_849300-MLA43693785678_102020-I.jpg',
#    'thumbnail_id': '849300-MLA43693785678_102020',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 303.5,
#     'rate': 0,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-SP',
#     'state_name': 'São Paulo',
#     'city_id': 'BR-SP-31',
#     'city_name': 'Osasco'},
#    'shipping': {'free_shipping': True,
#     'mode': 'me2',
#     'tags': ['self_service_in', 'mandatory_free_shipping'],
#     'logistic_type': 'xd_drop_off',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-SP', 'name': 'São Paulo'},
#     'city': {'id': 'BR-SP-31', 'name': 'Osasco'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'values': [{'name': 'Apple',
#        'struct': None,
#        'source': 1,
#        'id': '9344'}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'id': 'BRAND',
#      'value_id': '9344',
#      'value_name': 'Apple',
#      'name': 'Marca',
#      'value_struct': None},
#     {'value_struct': None,
#      'name': 'Condição do item',
#      'value_id': '2230284',
#      'value_name': 'Novo',
#      'values': [{'name': 'Novo',
#        'struct': None,
#        'source': 2860837171021627,
#        'id': '2230284'}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 2860837171021627,
#      'id': 'ITEM_CONDITION'},
#     {'name': 'Linha',
#      'value_name': 'iPhone',
#      'source': 1,
#      'id': 'LINE',
#      'value_id': '58993',
#      'value_struct': None,
#      'values': [{'struct': None,
#        'source': 1,
#        'id': '58993',
#        'name': 'iPhone'}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros'},
#     {'attribute_group_name': 'Outros',
#      'id': 'MODEL',
#      'value_struct': None,
#      'value_name': 'iPhone XR',
#      'values': [{'source': 1,
#        'id': '5414260',
#        'name': 'iPhone XR',
#        'struct': None}],
#      'attribute_group_id': 'OTHERS',
#      'source': 1,
#      'name': 'Modelo',
#      'value_id': '5414260'},
#     {'value_id': '6927771',
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'id': 'PROCESSOR_MODEL',
#      'name': 'Modelo do processador',
#      'value_name': 'Apple A12 Bionic',
#      'value_struct': None,
#      'values': [{'id': '6927771',
#        'name': 'Apple A12 Bionic',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS'},
#     {'name': 'Peso',
#      'value_id': '2583040',
#      'value_struct': {'number': 194, 'unit': 'g'},
#      'values': [{'id': '2583040',
#        'name': '194 g',
#        'struct': {'unit': 'g', 'number': 194},
#        'source': 1}],
#      'source': 1,
#      'id': 'WEIGHT',
#      'value_name': '194 g',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros'}],
#    'differential_pricing': {'id': 33580182},
#    'original_price': None,
#    'category_id': 'MLB1055',
#    'official_store_id': None,
#    'domain_id': 'MLB-CELLPHONES',
#    'catalog_product_id': 'MLB12866679',
#    'tags': ['extended_warranty_eligible',
#     'good_quality_picture',
#     'good_quality_thumbnail',
#     'loyalty_discount_eligible',
#     'immediate_payment',
#     'cart_eligible',
#     'shipping_guaranteed',
#     'meli_choice_candidate'],
#    'catalog_listing': True,
#    'use_thumbnail_id': True,
#    'order_backend': 4},
#   {'id': 'MLB1857350525',
#    'site_id': 'MLB',
#    'title': ' iPhone 8 Plus 64 Gb Prateado',
#    'seller': {'id': 418784891,
#     'permalink': 'http://perfil.mercadolivre.com.br/YESSHOPONLINE',
#     'registration_date': '2019-03-21T11:10:53.000-04:00',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': ['normal', 'messages_as_seller', 'messages_as_buyer'],
#     'seller_reputation': {'transactions': {'total': 7570,
#       'canceled': 901,
#       'period': 'historic',
#       'ratings': {'negative': 0.03, 'positive': 0.96, 'neutral': 0.01},
#       'completed': 6669},
#      'power_seller_status': None,
#      'metrics': {'claims': {'rate': 0.0285, 'value': 35, 'period': '60 days'},
#       'delayed_handling_time': {'rate': 0.0119,
#        'value': 13,
#        'period': '60 days'},
#       'sales': {'period': '60 days', 'completed': 1047},
#       'cancellations': {'rate': 0.0081, 'value': 10, 'period': '60 days'}},
#      'level_id': '5_green'}},
#    'price': 2822,
#    'prices': {'id': 'MLB1857350525',
#     'prices': [{'id': '11',
#       'type': 'standard',
#       'conditions': {'context_restrictions': [],
#        'start_time': None,
#        'end_time': None,
#        'eligible': True},
#       'amount': 2822,
#       'regular_amount': None,
#       'currency_id': 'BRL',
#       'exchange_rate_context': 'DEFAULT',
#       'metadata': {},
#       'last_updated': '2021-06-25T15:12:51Z'}],
#     'presentation': {'display_currency': 'BRL'},
#     'payment_method_prices': [],
#     'reference_prices': [],
#     'purchase_discounts': []},
#    'sale_price': None,
#    'currency_id': 'BRL',
#    'available_quantity': 12,
#    'sold_quantity': 29,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2041-04-10T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://www.mercadolivre.com.br/iphone-8-plus-64-gb-prateado/p/MLB8752452',
#    'thumbnail': 'http://http2.mlstatic.com/D_701783-MLA43711395860_102020-I.jpg',
#    'thumbnail_id': '701783-MLA43711395860_102020',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 235.17,
#     'rate': 0,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-PR',
#     'state_name': 'Paraná',
#     'city_id': 'TUxCQ0NVUjYyZmY1',
#     'city_name': 'Curitiba'},
#    'shipping': {'free_shipping': True,
#     'mode': 'me2',
#     'tags': ['mandatory_free_shipping'],
#     'logistic_type': 'cross_docking',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-PR', 'name': 'Paraná'},
#     'city': {'id': 'TUxCQ0NVUjYyZmY1', 'name': 'Curitiba'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'id': 'BRAND',
#      'value_id': '9344',
#      'value_name': 'Apple',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'name': 'Marca',
#      'values': [{'id': '9344', 'name': 'Apple', 'struct': None, 'source': 1}],
#      'attribute_group_name': 'Outros',
#      'source': 1},
#     {'attribute_group_id': 'OTHERS',
#      'value_id': '7741027',
#      'value_struct': None,
#      'values': [{'struct': None,
#        'source': 1,
#        'id': '7741027',
#        'name': 'Apple GPU'}],
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'id': 'GPU_MODEL',
#      'name': 'Modelo de GPU',
#      'value_name': 'Apple GPU'},
#     {'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 8021611602487823,
#      'id': 'ITEM_CONDITION',
#      'value_name': 'Novo',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Novo',
#        'struct': None,
#        'source': 8021611602487823}],
#      'name': 'Condição do item',
#      'value_id': '2230284'},
#     {'name': 'Linha',
#      'value_name': 'iPhone',
#      'value_struct': None,
#      'attribute_group_name': 'Outros',
#      'id': 'LINE',
#      'values': [{'id': '58993',
#        'name': 'iPhone',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'source': 1,
#      'value_id': '58993'},
#     {'id': 'MODEL',
#      'value_struct': None,
#      'values': [{'struct': None,
#        'source': 1,
#        'id': '2244673',
#        'name': 'iPhone 8 Plus'}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'name': 'Modelo',
#      'value_id': '2244673',
#      'value_name': 'iPhone 8 Plus'},
#     {'attribute_group_id': 'OTHERS',
#      'source': 1,
#      'id': 'PROCESSOR_MODEL',
#      'value_name': 'Apple A11 Bionic',
#      'value_struct': None,
#      'values': [{'id': '6936434',
#        'name': 'Apple A11 Bionic',
#        'struct': None,
#        'source': 1}],
#      'name': 'Modelo do processador',
#      'value_id': '6936434',
#      'attribute_group_name': 'Outros'},
#     {'source': 1,
#      'id': 'WEIGHT',
#      'name': 'Peso',
#      'values': [{'name': '202 g',
#        'struct': {'number': 202, 'unit': 'g'},
#        'source': 1,
#        'id': '2263677'}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'value_id': '2263677',
#      'value_name': '202 g',
#      'value_struct': {'number': 202, 'unit': 'g'}}],
#    'differential_pricing': {'id': 33580182},
#    'original_price': None,
#    'category_id': 'MLB1055',
#    'official_store_id': None,
#    'domain_id': 'MLB-CELLPHONES',
#    'catalog_product_id': 'MLB8752452',
#    'tags': ['catalog_boost',
#     'extended_warranty_eligible',
#     'good_quality_picture',
#     'good_quality_thumbnail',
#     'loyalty_discount_eligible',
#     'immediate_payment',
#     'cart_eligible',
#     'shipping_guaranteed'],
#    'catalog_listing': True,
#    'use_thumbnail_id': True,
#    'order_backend': 5},
#   {'id': 'MLB1755610685',
#    'site_id': 'MLB',
#    'title': 'Apple iPhone 12 Pro Max (128 Gb) - Prateado',
#    'seller': {'id': 54486513,
#     'permalink': 'http://perfil.mercadolivre.com.br/ROCHAVARIEDADESGO',
#     'registration_date': '2008-09-17T19:14:47.000-04:00',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': ['normal',
#      'credits_profile',
#      'mshops',
#      'messages_as_seller',
#      'messages_as_buyer'],
#     'seller_reputation': {'transactions': {'total': 1783,
#       'canceled': 211,
#       'period': 'historic',
#       'ratings': {'negative': 0, 'positive': 1, 'neutral': 0},
#       'completed': 1572},
#      'power_seller_status': 'gold',
#      'metrics': {'claims': {'rate': 0.0144, 'value': 3, 'period': '60 days'},
#       'delayed_handling_time': {'rate': 0.0937,
#        'value': 18,
#        'period': '60 days'},
#       'sales': {'period': '60 days', 'completed': 194},
#       'cancellations': {'rate': 0.0144, 'value': 3, 'period': '60 days'}},
#      'level_id': '5_green'}},
#    'price': 8790,
#    'prices': {'id': 'MLB1755610685',
#     'prices': [{'id': '12',
#       'type': 'standard',
#       'conditions': {'context_restrictions': [],
#        'start_time': None,
#        'end_time': None,
#        'eligible': True},
#       'amount': 8790,
#       'regular_amount': None,
#       'currency_id': 'BRL',
#       'exchange_rate_context': 'DEFAULT',
#       'metadata': {},
#       'last_updated': '2021-06-23T21:57:54Z'}],
#     'presentation': {'display_currency': 'BRL'},
#     'payment_method_prices': [],
#     'reference_prices': [],
#     'purchase_discounts': []},
#    'sale_price': None,
#    'currency_id': 'BRL',
#    'available_quantity': 4,
#    'sold_quantity': 1,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2040-12-30T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://www.mercadolivre.com.br/apple-iphone-12-pro-max-128-gb-prateado/p/MLB16163693',
#    'thumbnail': 'http://http2.mlstatic.com/D_765496-MLA46093155208_052021-I.jpg',
#    'thumbnail_id': '765496-MLA46093155208_052021',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 732.5,
#     'rate': 0,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-GO',
#     'state_name': 'Goiás',
#     'city_id': 'TUxR29p4m5pYQ',
#     'city_name': 'Goiânia'},
#    'shipping': {'free_shipping': True,
#     'mode': 'me2',
#     'tags': ['mandatory_free_shipping'],
#     'logistic_type': 'drop_off',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-GO', 'name': 'Goiás'},
#     'city': {'id': 'TUxR29p4m5pYQ', 'name': 'Goiânia'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'value_id': '9344',
#      'value_name': 'Apple',
#      'values': [{'name': 'Apple', 'struct': None, 'source': 1, 'id': '9344'}],
#      'attribute_group_id': 'OTHERS',
#      'id': 'BRAND',
#      'value_struct': None,
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'name': 'Marca'},
#     {'values': [{'id': '7741027',
#        'name': 'Apple GPU',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_name': 'Outros',
#      'id': 'GPU_MODEL',
#      'value_id': '7741027',
#      'value_name': 'Apple GPU',
#      'source': 1,
#      'name': 'Modelo de GPU',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS'},
#     {'id': 'ITEM_CONDITION',
#      'values': [{'id': '2230284',
#        'name': 'Novo',
#        'struct': None,
#        'source': 2860837171021627}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 2860837171021627,
#      'name': 'Condição do item',
#      'value_id': '2230284',
#      'value_name': 'Novo',
#      'value_struct': None},
#     {'id': 'LINE',
#      'values': [{'name': 'iPhone',
#        'struct': None,
#        'source': 1,
#        'id': '58993'}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'name': 'Linha',
#      'value_id': '58993',
#      'value_name': 'iPhone',
#      'value_struct': None},
#     {'name': 'Modelo',
#      'value_struct': None,
#      'values': [{'source': 1,
#        'id': '9081385',
#        'name': 'iPhone 12 Pro Max',
#        'struct': None}],
#      'attribute_group_id': 'OTHERS',
#      'source': 1,
#      'id': 'MODEL',
#      'value_id': '9081385',
#      'value_name': 'iPhone 12 Pro Max',
#      'attribute_group_name': 'Outros'},
#     {'value_name': 'Apple A14 Bionic',
#      'value_struct': None,
#      'values': [{'id': '9094177',
#        'name': 'Apple A14 Bionic',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_name': 'Outros',
#      'id': 'PROCESSOR_MODEL',
#      'name': 'Modelo do processador',
#      'value_id': '9094177',
#      'attribute_group_id': 'OTHERS',
#      'source': 1},
#     {'attribute_group_id': 'OTHERS',
#      'source': 1,
#      'name': 'Peso',
#      'value_id': '462004',
#      'value_struct': {'number': 228, 'unit': 'g'},
#      'values': [{'id': '462004',
#        'name': '228 g',
#        'struct': {'number': 228, 'unit': 'g'},
#        'source': 1}],
#      'attribute_group_name': 'Outros',
#      'id': 'WEIGHT',
#      'value_name': '228 g'}],
#    'differential_pricing': {'id': 33580182},
#    'original_price': None,
#    'category_id': 'MLB1055',
#    'official_store_id': None,
#    'domain_id': 'MLB-CELLPHONES',
#    'catalog_product_id': 'MLB16163693',
#    'tags': ['brand_verified',
#     'good_quality_picture',
#     'loyalty_discount_eligible',
#     'immediate_payment',
#     'cart_eligible',
#     'shipping_guaranteed'],
#    'catalog_listing': True,
#    'use_thumbnail_id': True,
#    'order_backend': 6},
#   {'id': 'MLB1927968106',
#    'site_id': 'MLB',
#    'title': ' iPhone 8 64 Gb Cinza-espacial',
#    'seller': {'id': 131333084,
#     'permalink': 'http://perfil.mercadolivre.com.br/EXPRESS+SHOP-E',
#     'registration_date': '2013-01-03T22:34:02.000-04:00',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': ['normal',
#      'credits_profile',
#      'mshops',
#      'messages_as_seller',
#      'messages_as_buyer'],
#     'seller_reputation': {'transactions': {'total': 23,
#       'canceled': 1,
#       'period': 'historic',
#       'ratings': {'negative': 0, 'positive': 1, 'neutral': 0},
#       'completed': 22},
#      'power_seller_status': None,
#      'metrics': {'claims': {'rate': 0, 'value': 0, 'period': '365 days'},
#       'delayed_handling_time': {'rate': 0, 'value': 0, 'period': '365 days'},
#       'sales': {'period': '365 days', 'completed': 22},
#       'cancellations': {'rate': 0, 'value': 0, 'period': '365 days'}},
#      'level_id': '5_green'}},
#    'price': 2049,
#    'prices': {'id': 'MLB1927968106',
#     'prices': [{'id': '2',
#       'type': 'standard',
#       'conditions': {'context_restrictions': [],
#        'start_time': None,
#        'end_time': None,
#        'eligible': True},
#       'amount': 2049,
#       'regular_amount': None,
#       'currency_id': 'BRL',
#       'exchange_rate_context': 'DEFAULT',
#       'metadata': {},
#       'last_updated': '2021-06-25T15:41:21Z'}],
#     'presentation': {'display_currency': 'BRL'},
#     'payment_method_prices': [],
#     'reference_prices': [],
#     'purchase_discounts': []},
#    'sale_price': None,
#    'currency_id': 'BRL',
#    'available_quantity': 1,
#    'sold_quantity': 0,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_special',
#    'stop_time': '2041-06-19T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://www.mercadolivre.com.br/iphone-8-64-gb-cinza-espacial/p/MLB8752432',
#    'thumbnail': 'http://http2.mlstatic.com/D_819468-MLA43694219099_102020-I.jpg',
#    'thumbnail_id': '819468-MLA43694219099_102020',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 194.64,
#     'rate': 13.99,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-ES',
#     'state_name': 'Espírito Santo',
#     'city_id': 'TUxCQ1ZJTGU5YTdl',
#     'city_name': 'Vila Velha'},
#    'shipping': {'free_shipping': True,
#     'mode': 'me2',
#     'tags': ['mandatory_free_shipping'],
#     'logistic_type': 'drop_off',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-ES', 'name': 'Espírito Santo'},
#     'city': {'id': 'TUxCQ1ZJTGU5YTdl', 'name': 'Vila Velha'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'values': [{'source': 1,
#        'id': '9344',
#        'name': 'Apple',
#        'struct': None}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'name': 'Marca',
#      'value_id': '9344',
#      'value_name': 'Apple',
#      'id': 'BRAND',
#      'value_struct': None,
#      'source': 1},
#     {'value_id': '2230284',
#      'values': [{'id': '2230284',
#        'name': 'Novo',
#        'struct': None,
#        'source': 2860837171021627}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'id': 'ITEM_CONDITION',
#      'name': 'Condição do item',
#      'source': 2860837171021627,
#      'value_name': 'Novo',
#      'value_struct': None},
#     {'value_name': 'iPhone',
#      'attribute_group_name': 'Outros',
#      'attribute_group_id': 'OTHERS',
#      'source': 1,
#      'id': 'LINE',
#      'name': 'Linha',
#      'value_id': '58993',
#      'value_struct': None,
#      'values': [{'id': '58993',
#        'name': 'iPhone',
#        'struct': None,
#        'source': 1}]},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'value_id': '2244670',
#      'value_name': 'iPhone 8',
#      'value_struct': None,
#      'values': [{'id': '2244670',
#        'name': 'iPhone 8',
#        'struct': None,
#        'source': 1}]},
#     {'id': 'PROCESSOR_MODEL',
#      'name': 'Modelo do processador',
#      'value_name': 'Apple A11 Bionic',
#      'values': [{'id': '6936434',
#        'name': 'Apple A11 Bionic',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'value_id': '6936434',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS'},
#     {'value_id': '6861161',
#      'value_name': '148 g',
#      'values': [{'name': '148 g',
#        'struct': {'number': 148, 'unit': 'g'},
#        'source': 1,
#        'id': '6861161'}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'id': 'WEIGHT',
#      'name': 'Peso',
#      'value_struct': {'unit': 'g', 'number': 148},
#      'source': 1}],
#    'original_price': None,
#    'category_id': 'MLB1055',
#    'official_store_id': None,
#    'domain_id': 'MLB-CELLPHONES',
#    'catalog_product_id': 'MLB8752432',
#    'tags': ['extended_warranty_eligible',
#     'good_quality_picture',
#     'immediate_payment',
#     'cart_eligible'],
#    'catalog_listing': True,
#    'use_thumbnail_id': True,
#    'order_backend': 7},
#   {'id': 'MLB1925505282',
#    'site_id': 'MLB',
#    'title': 'Apple iPhone 12 (64 Gb) - Branco',
#    'seller': {'id': 708615982,
#     'permalink': 'http://perfil.mercadolivre.com.br/JS+MOBILESP',
#     'registration_date': '2021-01-30T06:35:07.000-04:00',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': ['normal', 'messages_as_seller', 'messages_as_buyer'],
#     'seller_reputation': {'transactions': {'total': 73,
#       'canceled': 3,
#       'period': 'historic',
#       'ratings': {'negative': 0, 'positive': 1, 'neutral': 0},
#       'completed': 70},
#      'power_seller_status': None,
#      'metrics': {'claims': {'rate': 0, 'value': 0, 'period': '365 days'},
#       'delayed_handling_time': {'rate': 0.0307,
#        'value': 2,
#        'period': '365 days'},
#       'sales': {'period': '365 days', 'completed': 70},
#       'cancellations': {'rate': 0, 'value': 0, 'period': '365 days'}},
#      'level_id': '5_green'}},
#    'price': 6395,
#    'prices': {'id': 'MLB1925505282',
#     'prices': [{'id': '3',
#       'type': 'standard',
#       'conditions': {'context_restrictions': [],
#        'start_time': None,
#        'end_time': None,
#        'eligible': True},
#       'amount': 6395,
#       'regular_amount': None,
#       'currency_id': 'BRL',
#       'exchange_rate_context': 'DEFAULT',
#       'metadata': {},
#       'last_updated': '2021-06-23T14:18:05Z'}],
#     'presentation': {'display_currency': 'BRL'},
#     'payment_method_prices': [],
#     'reference_prices': [],
#     'purchase_discounts': []},
#    'sale_price': None,
#    'currency_id': 'BRL',
#    'available_quantity': 1,
#    'sold_quantity': 0,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2041-06-17T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://www.mercadolivre.com.br/apple-iphone-12-64-gb-branco/p/MLB16163647',
#    'thumbnail': 'http://http2.mlstatic.com/D_779793-MLA46082237487_052021-I.jpg',
#    'thumbnail_id': '779793-MLA46082237487_052021',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 532.92,
#     'rate': 0,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-SP',
#     'state_name': 'São Paulo',
#     'city_id': 'BR-SP-70',
#     'city_name': 'Araraquara'},
#    'shipping': {'free_shipping': True,
#     'mode': 'me2',
#     'tags': ['mandatory_free_shipping'],
#     'logistic_type': 'xd_drop_off',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-SP', 'name': 'São Paulo'},
#     'city': {'id': 'BR-SP-70', 'name': 'Araraquara'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'source': 1,
#      'value_id': '9344',
#      'value_name': 'Apple',
#      'value_struct': None,
#      'attribute_group_name': 'Outros',
#      'id': 'BRAND',
#      'name': 'Marca',
#      'values': [{'id': '9344', 'name': 'Apple', 'struct': None, 'source': 1}],
#      'attribute_group_id': 'OTHERS'},
#     {'value_name': 'Novo',
#      'value_struct': None,
#      'source': 3045741222775799,
#      'id': 'ITEM_CONDITION',
#      'name': 'Condição do item',
#      'value_id': '2230284',
#      'values': [{'struct': None,
#        'source': 3045741222775799,
#        'id': '2230284',
#        'name': 'Novo'}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros'},
#     {'id': 'LINE',
#      'attribute_group_id': 'OTHERS',
#      'source': 1,
#      'value_struct': None,
#      'values': [{'name': 'iPhone',
#        'struct': None,
#        'source': 1,
#        'id': '58993'}],
#      'attribute_group_name': 'Outros',
#      'name': 'Linha',
#      'value_id': '58993',
#      'value_name': 'iPhone'},
#     {'value_id': '9081382',
#      'value_name': 'iPhone 12',
#      'values': [{'id': '9081382',
#        'name': 'iPhone 12',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'id': 'MODEL',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'name': 'Modelo'},
#     {'id': 'PROCESSOR_MODEL',
#      'values': [{'source': 1,
#        'id': '9094177',
#        'name': 'Apple A14 Bionic',
#        'struct': None}],
#      'source': 1,
#      'name': 'Modelo do processador',
#      'value_id': '9094177',
#      'value_name': 'Apple A14 Bionic',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros'}],
#    'differential_pricing': {'id': 33580182},
#    'original_price': None,
#    'category_id': 'MLB1055',
#    'official_store_id': None,
#    'domain_id': 'MLB-CELLPHONES',
#    'catalog_product_id': 'MLB16163647',
#    'tags': ['good_quality_picture',
#     'immediate_payment',
#     'cart_eligible',
#     'shipping_guaranteed',
#     'meli_choice_candidate'],
#    'catalog_listing': True,
#    'use_thumbnail_id': True,
#    'order_backend': 8},
#   {'id': 'MLB1929176710',
#    'site_id': 'MLB',
#    'title': 'Apple iPhone 12 Pro Max (256 Gb) - Grafite',
#    'seller': {'id': 681521977,
#     'permalink': 'http://perfil.mercadolivre.com.br/CONECTAAUTOPARTS',
#     'registration_date': '2020-12-02T12:17:24.000-04:00',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': ['normal', 'mshops', 'messages_as_seller'],
#     'seller_reputation': {'transactions': {'total': 34,
#       'canceled': 3,
#       'period': 'historic',
#       'ratings': {'negative': 0, 'positive': 1, 'neutral': 0},
#       'completed': 31},
#      'power_seller_status': None,
#      'metrics': {'claims': {'rate': 0, 'value': 0, 'period': '365 days'},
#       'delayed_handling_time': {'rate': 0, 'value': 0, 'period': '365 days'},
#       'sales': {'period': '365 days', 'completed': 31},
#       'cancellations': {'rate': 0, 'value': 0, 'period': '365 days'}},
#      'level_id': '5_green'}},
#    'price': 9100,
#    'prices': {'id': 'MLB1929176710',
#     'prices': [{'id': '2',
#       'type': 'standard',
#       'conditions': {'context_restrictions': [],
#        'start_time': None,
#        'end_time': None,
#        'eligible': True},
#       'amount': 9100,
#       'regular_amount': None,
#       'currency_id': 'BRL',
#       'exchange_rate_context': 'DEFAULT',
#       'metadata': {},
#       'last_updated': '2021-06-26T00:56:03Z'}],
#     'presentation': {'display_currency': 'BRL'},
#     'payment_method_prices': [],
#     'reference_prices': [],
#     'purchase_discounts': []},
#    'sale_price': None,
#    'currency_id': 'BRL',
#    'available_quantity': 1,
#    'sold_quantity': 0,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2041-06-21T00:54:17.000Z',
#    'condition': 'new',
#    'permalink': 'https://www.mercadolivre.com.br/apple-iphone-12-pro-max-256-gb-grafite/p/MLB16163696',
#    'thumbnail': 'http://http2.mlstatic.com/D_792396-MLA46093213172_052021-I.jpg',
#    'thumbnail_id': '792396-MLA46093213172_052021',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 758.33,
#     'rate': 0,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-PR',
#     'state_name': 'Paraná',
#     'city_id': 'TUxCQ0NBU2NiZTll',
#     'city_name': 'Cascavel'},
#    'shipping': {'free_shipping': True,
#     'mode': 'me2',
#     'tags': ['mandatory_free_shipping'],
#     'logistic_type': 'drop_off',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-PR', 'name': 'Paraná'},
#     'city': {'id': 'TUxCQ0NBU2NiZTll', 'name': 'Cascavel'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'value_id': '9344',
#      'value_name': 'Apple',
#      'values': [{'struct': None, 'source': 1, 'id': '9344', 'name': 'Apple'}],
#      'id': 'BRAND',
#      'name': 'Marca',
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS'},
#     {'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'name': 'Modelo de GPU',
#      'value_id': '7741027',
#      'value_name': 'Apple GPU',
#      'values': [{'id': '7741027',
#        'name': 'Apple GPU',
#        'struct': None,
#        'source': 1}],
#      'id': 'GPU_MODEL',
#      'value_struct': None,
#      'source': 1},
#     {'attribute_group_id': 'OTHERS',
#      'source': 2860837171021627,
#      'value_name': 'Novo',
#      'values': [{'struct': None,
#        'source': 2860837171021627,
#        'id': '2230284',
#        'name': 'Novo'}],
#      'value_id': '2230284',
#      'value_struct': None,
#      'attribute_group_name': 'Outros',
#      'id': 'ITEM_CONDITION',
#      'name': 'Condição do item'},
#     {'name': 'Linha',
#      'value_id': '58993',
#      'value_struct': None,
#      'values': [{'id': '58993',
#        'name': 'iPhone',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'source': 1,
#      'id': 'LINE',
#      'value_name': 'iPhone',
#      'attribute_group_name': 'Outros'},
# ...
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2040-05-13T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://produto.mercadolivre.com.br/MLB-1527524183-iphone-8-64gb-vitrine-apple-tela-47-em-12x-sem-juros-_JM',
#    'thumbnail': 'http://http2.mlstatic.com/D_676727-MLA41314839082_042020-O.jpg',
#    'thumbnail_id': '676727-MLA41314839082_042020',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 174.83,
#     'rate': 0,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-SP',
#     'state_name': 'São Paulo',
#     'city_id': 'BR-SP-44',
#     'city_name': 'São Paulo'},
#    'shipping': {'free_shipping': True,
#     'mode': 'me2',
#     'tags': ['self_service_in', 'mandatory_free_shipping'],
#     'logistic_type': 'xd_drop_off',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-SP', 'name': 'São Paulo'},
#     'city': {'id': 'BR-SP-44', 'name': 'São Paulo'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'name': 'Marca',
#      'value_id': '9344',
#      'value_name': 'Apple',
#      'source': 6808261514773724,
#      'id': 'BRAND',
#      'value_struct': None,
#      'values': [{'source': 6808261514773724,
#        'id': '9344',
#        'name': 'Apple',
#        'struct': None}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros'},
#     {'name': 'Condição do item',
#      'attribute_group_name': 'Outros',
#      'source': 6808261514773724,
#      'id': 'ITEM_CONDITION',
#      'value_id': '2230284',
#      'value_name': 'Novo',
#      'value_struct': None,
#      'values': [{'name': 'Novo',
#        'struct': None,
#        'source': 6808261514773724,
#        'id': '2230284'}],
#      'attribute_group_id': 'OTHERS'},
#     {'value_id': '58993',
#      'value_name': 'iPhone',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'source': 6808261514773724,
#      'id': 'LINE',
#      'values': [{'id': '58993',
#        'name': 'iPhone',
#        'struct': None,
#        'source': 6808261514773724}],
#      'attribute_group_name': 'Outros',
#      'name': 'Linha'},
#     {'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'id': 'MODEL',
#      'value_id': '2244670',
#      'value_name': 'iPhone 8',
#      'source': 6808261514773724,
#      'name': 'Modelo',
#      'value_struct': None,
#      'values': [{'id': '2244670',
#        'name': 'iPhone 8',
#        'struct': None,
#        'source': 6808261514773724}]},
#     {'value_id': '6936434',
#      'value_name': 'Apple A11 Bionic',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 6808261514773724,
#      'id': 'PROCESSOR_MODEL',
#      'name': 'Modelo do processador',
#      'value_struct': None,
#      'values': [{'id': '6936434',
#        'name': 'Apple A11 Bionic',
#        'struct': None,
#        'source': 6808261514773724}]},
#     {'value_id': '6861161',
#      'attribute_group_name': 'Outros',
#      'id': 'WEIGHT',
#      'name': 'Peso',
#      'value_name': '148 g',
#      'value_struct': {'number': 148, 'unit': 'g'},
#      'values': [{'source': 6808261514773724,
#        'id': '6861161',
#        'name': '148 g',
#        'struct': {'number': 148, 'unit': 'g'}}],
#      'attribute_group_id': 'OTHERS',
#      'source': 6808261514773724}],
#    'differential_pricing': {'id': 33580182},
#    'original_price': None,
#    'category_id': 'MLB1055',
#    'official_store_id': None,
#    'domain_id': 'MLB-CELLPHONES',
#    'catalog_product_id': 'MLB8752429',
#    'tags': ['brand_verified',
#     'extended_warranty_eligible',
#     'good_quality_picture',
#     'good_quality_thumbnail',
#     'loyalty_discount_eligible',
#     'immediate_payment',
#     'cart_eligible',
#     'shipping_guaranteed',
#     'best_seller_candidate'],
#    'order_backend': 50,
#    'use_thumbnail_id': False}],
#  'secondary_results': [],
#  'related_results': [],
#  'sort': {'id': 'relevance', 'name': 'Mais relevantes'},
#  'available_sorts': [{'id': 'price_asc', 'name': 'Menor preço'},
#   {'id': 'price_desc', 'name': 'Maior preço'}],
#  'filters': [{'id': 'category',
#    'name': 'Categorias',
#    'type': 'text',
#    'values': [{'id': 'MLB1055',
#      'name': 'Celulares e Smartphones',
#      'path_from_root': [{'id': 'MLB1051', 'name': 'Celulares e Telefones'},
#       {'id': 'MLB1055', 'name': 'Celulares e Smartphones'}]}]},
#   {'id': 'BRAND',
#    'name': 'Marca',
#    'type': 'STRING',
#    'values': [{'id': '9344', 'name': 'Apple'}]},
#   {'id': 'LINE',
#    'name': 'Linha',
#    'type': 'STRING',
#    'values': [{'id': '58993', 'name': 'iPhone'}]}],
#  'available_filters': [{'id': 'official_store',
#    'name': 'Lojas oficiais',
#    'type': 'text',
#    'values': [{'id': 'all', 'name': 'Todas as Lojas oficiais', 'results': 646},
#     {'id': '942', 'name': 'Fast Shop', 'results': 30}]},
#   {'id': 'discount',
#    'name': 'Descontos',
#    'type': 'range',
#    'values': [{'id': '5-100', 'name': 'Mais de 5% OFF', 'results': 15},
#     {'id': '10-100', 'name': 'Mais de 10% OFF', 'results': 5},
#     {'id': '20-100', 'name': 'Mais de 20% OFF', 'results': 1}]},
#   {'id': 'state',
#    'name': 'Localização',
#    'type': 'text',
#    'values': [{'id': 'TUxCUFNBT085N2E4',
#      'name': 'São Paulo',
#      'results': 16290},
#     {'id': 'TUxCUE1JTlMxNTAyZA', 'name': 'Minas Gerais', 'results': 3972},
#     {'id': 'TUxCUFJJT08xODM5Zg', 'name': 'Rio de Janeiro', 'results': 3577},
#     {'id': 'TUxCUFBBUkExODBlZA', 'name': 'Paraná', 'results': 2104},
#     {'id': 'TUxCUFJJT0xkYzM0', 'name': 'Rio Grande do Sul', 'results': 1564},
#     {'id': 'TUxCUEJBSEFlYmEx', 'name': 'Bahia', 'results': 1476},
#     {'id': 'TUxCUFNBTkE5Nzc4', 'name': 'Santa Catarina', 'results': 1476},
#     {'id': 'TUxCUEdPSVMxNzVmMw', 'name': 'Goiás', 'results': 1120},
#     {'id': 'TUxCUERJU0wxMWJhYg', 'name': 'Distrito Federal', 'results': 956},
#     {'id': 'TUxCUENFQUExNzkyZQ', 'name': 'Ceará', 'results': 708},
#     {'id': 'TUxCUFBFUk8xZmZj', 'name': 'Pernambuco', 'results': 632},
#     {'id': 'TUxCUEVTUE8xN2Y3NA', 'name': 'Espírito Santo', 'results': 561},
#     {'id': 'TUxCUE1BVEw4ZTc', 'name': 'Mato Grosso do Sul', 'results': 408},
#     {'id': 'TUxCUE1BVE9jZDY0', 'name': 'Mato Grosso', 'results': 344},
#     {'id': 'TUxCUFBBUkFiY2Uw', 'name': 'Pará', 'results': 332},
#     {'id': 'TUxCUE1BUk81MWVi', 'name': 'Maranhão', 'results': 296},
#     {'id': 'TUxCUFBBUkE0M2I4', 'name': 'Paraíba', 'results': 236},
#     {'id': 'TUxCUEFMQVNmZjUw', 'name': 'Alagoas', 'results': 224},
#     {'id': 'TUxCUFNFUkUxMmZlOQ', 'name': 'Sergipe', 'results': 216},
#     {'id': 'TUxCUFBJQUk1NDVj', 'name': 'Piauí', 'results': 196},
#     {'id': 'TUxCUEFNQVMxNzgwYQ', 'name': 'Amazonas', 'results': 192},
#     {'id': 'TUxCUFJJT0VkMmNj', 'name': 'Rio Grande do Norte', 'results': 188},
#     {'id': 'TUxCUFJPTkExMmU4YQ', 'name': 'Rondônia', 'results': 128},
#     {'id': 'TUxCUEFNQUExNTZlNg', 'name': 'Amapá', 'results': 72},
#     {'id': 'TUxCUFRPQ1NjZDBm', 'name': 'Tocantins', 'results': 68},
#     {'id': 'TUxCUEFDUkVkNTU', 'name': 'Acre', 'results': 40},
#     {'id': 'TUxCUFJPUkExODBiMQ', 'name': 'Roraima', 'results': 32}]},
#   {'id': 'price',
#    'name': 'Preço',
#    'type': 'range',
#    'values': [{'id': '*-1000.0', 'name': 'Até R$1.000', 'results': 8203},
#     {'id': '1000.0-2500.0', 'name': 'R$1.000 a R$2.500', 'results': 16408},
#     {'id': '2500.0-*', 'name': 'Mais de R$2.500', 'results': 12933}]},
#   {'id': 'accepts_mercadopago',
#    'name': 'Filtro por MercadoPago',
#    'type': 'boolean',
#    'values': [{'id': 'yes', 'name': 'Com MercadoPago', 'results': 37544}]},
#   {'id': 'installments',
#    'name': 'Pagamento',
#    'type': 'text',
#    'values': [{'id': 'no_interest', 'name': 'Sem juros', 'results': 9728}]},
#   {'id': 'shipping',
#    'name': 'Tipo de envio',
#    'type': 'text',
#    'values': [{'id': 'mercadoenvios',
#      'name': 'Mercado Envios',
#      'results': 37524},
#     {'id': 'fulfillment', 'name': 'Full', 'results': 4}]},
#   {'id': 'power_seller',
#    'name': 'Filtro MercadoLíderes',
#    'type': 'boolean',
#    'values': [{'id': 'yes', 'name': 'Melhores vendedores', 'results': 1087}]},
#   {'id': 'since',
#    'name': 'Filtro por data de início',
#    'type': 'text',
#    'values': [{'id': 'today', 'name': 'Anunciados hoje', 'results': 804}]},
#   {'id': 'until',
#    'name': 'Filtro por data do fim',
#    'type': 'text',
#    'values': [{'id': 'today', 'name': 'Termina hoje', 'results': 292}]},
#   {'id': 'has_video',
#    'name': 'Filtro por publicações com vídeo',
#    'type': 'boolean',
#    'values': [{'id': 'yes',
#      'name': 'Publicações com vídeo',
#      'results': 1152}]},
#   {'id': 'has_pictures',
#    'name': 'Filtro por publicação com imagens',
#    'type': 'boolean',
#    'values': [{'id': 'yes', 'name': 'Com fotos', 'results': 37464}]},
#   {'id': 'shipping_cost',
#    'name': 'Custo do frete',
#    'type': 'text',
#    'values': [{'id': 'free', 'name': 'Gratis', 'results': 20201}]},
#   {'id': 'CARRIER',
#    'name': 'Operadora',
#    'type': 'STRING',
#    'values': [{'id': '298335', 'name': 'Desbloqueado', 'results': 25569},
#     {'id': '298332', 'name': 'Vivo', 'results': 411},
#     {'id': '298334', 'name': 'TIM', 'results': 270},
#     {'id': '298333', 'name': 'Claro', 'results': 237},
#     {'id': '298331', 'name': 'Oi', 'results': 129},
#     {'id': '303172', 'name': 'Nextel', 'results': 24}]},
#   {'id': 'DISPLAY_SIZE',
#    'name': 'Tamanho da tela',
#    'type': 'range',
#    'values': [{'id': '(*-5.5")', 'name': 'Menos de 5,5 "', 'results': 15084},
#     {'id': '[5.5"-5.8")', 'name': '5,5 a 5,7 "', 'results': 5382},
#     {'id': '[5.8"-6.5")', 'name': '5,8 a 6,4 "', 'results': 6009},
#     {'id': '[6.5"-*)', 'name': '6,5 " ou mais', 'results': 1434}]},
#   {'id': 'INTERNAL_MEMORY',
#    'name': 'Memória interna',
#    'type': 'range',
#    'values': [{'id': '(*-64GB)', 'name': 'Menos de 64 GB', 'results': 9774},
#     {'id': '[64GB-128GB)', 'name': '64 a 127 GB', 'results': 10164},
#     {'id': '[128GB-256GB)', 'name': '128 a 255 GB', 'results': 5127},
#     {'id': '[256GB-*)', 'name': '256 GB ou mais', 'results': 3267}]},
#   {'id': 'IS_DUAL_SIM',
#    'name': 'Outras características',
#    'type': 'boolean',
#    'values': [{'id': '242085', 'name': 'É Dual SIM', 'results': 732}]},
#   {'id': 'IS_WATER_RESISTANT',
#    'name': 'Outras características',
#    'type': 'boolean',
#    'values': [{'id': '242085',
#      'name': 'É resistente à água',
#      'results': 19521}]},
#   {'id': 'ITEM_CONDITION',
#    'name': 'Condição',
#    'type': 'STRING',
#    'values': [{'id': '2230581', 'name': 'Usado', 'results': 24243},
#     {'id': '2230284', 'name': 'Novo', 'results': 3411},
#     {'id': '2230582', 'name': 'Recondicionado', 'results': 705}]},
#   {'id': 'MAIN_COLOR',
#    'name': 'Cor principal',
#    'type': 'list',
#    'values': [{'id': '2450294', 'name': 'Cinza', 'results': 7716},
#     {'id': '2450295', 'name': 'Preto', 'results': 4836},
#     {'id': '2450289', 'name': 'Dourado', 'results': 3621},
#     {'id': '2450312', 'name': 'Rosa', 'results': 2562},
#     {'id': '2450308', 'name': 'Branco', 'results': 1332},
#     {'id': '2450307', 'name': 'Vermelho', 'results': 1032},
#     {'id': '2450293', 'name': 'Azul', 'results': 399},
#     {'id': '2450314', 'name': 'Verde', 'results': 333},
#     {'id': '2450303', 'name': 'Prateado', 'results': 108},
#     {'id': '2450296', 'name': 'Amarelo', 'results': 78},
#     {'id': '2450311', 'name': 'Violeta', 'results': 48},
#     {'id': '2450299', 'name': 'Cinza-escuro', 'results': 33},
#     {'id': '2450280', 'name': 'Rosa-claro', 'results': 27},
#     {'id': '2450313', 'name': 'Coral-claro', 'results': 9},
#     {'id': '2450309', 'name': 'Dourado-escuro', 'results': 9}]},
#   {'id': 'MAIN_FRONT_CAMERA_RESOLUTION',
#    'name': 'Resolução da câmera frontal principal',
#    'type': 'range',
#    'values': [{'id': '(*-7Mpx)', 'name': '7 Mpx ou menos', 'results': 8256},
#     {'id': '[7Mpx-12Mpx)', 'name': '7 a 11 Mpx', 'results': 16413},
#     {'id': '[12Mpx-*)', 'name': '12 Mpx ou mais', 'results': 2937}]},
#   {'id': 'MOBILE_NETWORK',
#    'name': 'Rede',
#    'type': 'STRING',
#    'values': [{'id': '367876', 'name': '4G/LTE', 'results': 24138},
#     {'id': '7472027', 'name': '5G', 'results': 1062},
#     {'id': '367874', 'name': '3G', 'results': 471},
#     {'id': '7472026', 'name': '2G', 'results': 273}]},
#   {'id': 'MODEL',
#    'name': 'Modelo',
#    'type': 'STRING',
#    'values': [{'id': '312155', 'name': 'iPhone 7', 'results': 4401},
#     {'id': '2244670', 'name': 'iPhone 8', 'results': 2619},
#     {'id': '312151', 'name': 'iPhone 6s', 'results': 2592},
#     {'id': '2244673', 'name': 'iPhone 8 Plus', 'results': 2280},
#     {'id': '312157', 'name': 'iPhone 7 Plus', 'results': 2208},
#     {'id': '5414260', 'name': 'iPhone XR', 'results': 1572},
#     {'id': '1164456', 'name': 'iPhone X', 'results': 1536},
#     {'id': '312149', 'name': 'iPhone 6', 'results': 1530},
#     {'id': '312144', 'name': 'iPhone 5s', 'results': 1245},
#     {'id': '7739079', 'name': 'iPhone 11', 'results': 1032},
#     {'id': '312154', 'name': 'iPhone SE', 'results': 648},
#     {'id': '5414168', 'name': 'iPhone XS Max', 'results': 576},
#     {'id': '7741677', 'name': 'iPhone 11 Pro Max', 'results': 492},
#     {'id': '312145', 'name': 'iPhone 4s', 'results': 471},
#     {'id': '312153', 'name': 'iPhone 6s Plus', 'results': 417},
#     {'id': '5414079', 'name': 'iPhone XS', 'results': 402},
#     {'id': '312152', 'name': 'iPhone 5', 'results': 402},
#     {'id': '9081382', 'name': 'iPhone 12', 'results': 396},
#     {'id': '312150', 'name': 'iPhone 6 Plus', 'results': 369},
#     {'id': '9081385', 'name': 'iPhone 12 Pro Max', 'results': 357},
#     {'id': '14608', 'name': 'iPhone', 'results': 339},
#     {'id': '7741023', 'name': 'iPhone 11 Pro', 'results': 336},
#     {'id': '312143', 'name': 'iPhone 5c', 'results': 285},
#     {'id': '14610', 'name': 'iPhone 4', 'results': 279},
#     {'id': '9081384', 'name': 'iPhone 12 Pro', 'results': 168},
#     {'id': '5414092', 'name': 'iPhone XS Dual SIM', 'results': 153},
#     {'id': '9081383', 'name': 'iPhone 12 mini', 'results': 132},
#     {'id': '8230322', 'name': 'iPhone SE (2nd Generation)', 'results': 111},
#     {'id': '9676776', 'name': '6s', 'results': 105},
#     {'id': '27251', 'name': '7', 'results': 57},
#     {'id': '14609', 'name': 'iPhone 3GS', 'results': 51},
#     {'id': '52828', 'name': '7 Plus', 'results': 42},
#     {'id': '14605', 'name': 'iPhone 3G', 'results': 39},
#     {'id': '58615', 'name': '5', 'results': 18},
#     {'id': '58054', 'name': 'XR', 'results': 12},
#     {'id': '59833', 'name': '6', 'results': 9},
#     {'id': '11043', 'name': '8', 'results': 9}]},
#   {'id': 'OPERATING_SYSTEM_NAME',
#    'name': 'Nome do sistema operacional',
#    'type': 'STRING',
#    'values': [{'id': '7404961', 'name': 'iOS', 'results': 28032}]},
#   {'id': 'RAM',
#    'name': 'Memória RAM',
#    'type': 'range',
#    'values': [{'id': '(*-2GB]', 'name': '2 GB ou menos', 'results': 13590},
#     {'id': '[3GB-3GB]', 'name': '3 GB', 'results': 7104},
#     {'id': '[4GB-4GB]', 'name': '4 GB', 'results': 3627},
#     {'id': '[5GB-5GB]', 'name': '5 GB', 'results': 120},
#     {'id': '[6GB-6GB]', 'name': '6 GB', 'results': 621},
#     {'id': '[7GB-7GB]', 'name': '7 GB', 'results': 9},
#     {'id': '[8GB-*)', 'name': '8 GB ou mais', 'results': 1869}]},
#   {'id': 'SHIPPING_ORIGIN',
#    'name': 'Tipo de compra',
#    'type': 'STRING',
#    'values': [{'id': '10215068', 'name': 'Local', 'results': 28383}]},
#   {'id': 'WITH_FACIAL_RECOGNITION',
#    'name': 'Outras características',
#    'type': 'boolean',
#    'values': [{'id': '242085',
#      'name': 'Com reconhecimento facial',
#      'results': 7614}]},
#   {'id': 'WITH_FAST_CHARGING',
#    'name': 'Outras características',
#    'type': 'boolean',
#    'values': [{'id': '242085',
#      'name': 'Com carregamento rápido',
#      'results': 9483}]},
#   {'id': 'WITH_FINGERPRINT_READER',
#    'name': 'Outras características',
#    'type': 'boolean',
#    'values': [{'id': '242085',
#      'name': 'Com leitor de impressão digital',
#      'results': 18729}]},
#   {'id': 'WITH_NFC',
#    'name': 'Outras características',
#    'type': 'boolean',
#    'values': [{'id': '242085', 'name': 'Com NFC', 'results': 22635}]}]}

# %%
temp = busca('iphone')

# %%
temp
# Out:
# {'site_id': 'MLB',
#  'query': 'iphone',
#  'paging': {'total': 37596, 'primary_results': 1000, 'offset': 0, 'limit': 50},
#  'results': [{'id': 'MLB1729453817',
#    'site_id': 'MLB',
#    'title': 'Apple iPhone 11 (128 Gb) - Branco',
#    'seller': {'id': 234000251,
#     'permalink': 'http://perfil.mercadolivre.com.br/FASTSHOP+OFICIAL',
#     'registration_date': '2016-11-09T09:05:35.000-04:00',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': ['brand',
#      'large_seller',
#      'mshops',
#      'messages_as_seller',
#      'messages_as_buyer'],
#     'seller_reputation': {'transactions': {'total': 164024,
#       'canceled': 10534,
#       'period': 'historic',
#       'ratings': {'negative': 0.02, 'positive': 0.94, 'neutral': 0.04},
#       'completed': 153490},
#      'power_seller_status': None,
#      'metrics': {'claims': {'rate': 0.0114, 'value': 178, 'period': '60 days'},
#       'delayed_handling_time': {'rate': 0.1214,
#        'value': 511,
#        'period': '60 days'},
#       'sales': {'period': '60 days', 'completed': 14492},
#       'cancellations': {'rate': 0.0254, 'value': 394, 'period': '60 days'}},
#      'level_id': '5_green'}},
#    'price': 4454,
#    'prices': {'id': 'MLB1729453817',
#     'prices': [{'id': '55',
#       'type': 'standard',
#       'conditions': {'context_restrictions': [],
#        'start_time': None,
#        'end_time': None,
#        'eligible': True},
#       'amount': 4499,
#       'regular_amount': None,
#       'currency_id': 'BRL',
#       'exchange_rate_context': 'DEFAULT',
#       'metadata': {},
#       'last_updated': '2021-06-23T12:52:06Z'},
#      {'id': '61',
#       'type': 'promotion',
#       'conditions': {'context_restrictions': [],
#        'start_time': '2021-06-25T03:00:00Z',
#        'end_time': '2021-06-26T02:59:59Z',
#        'eligible': True},
#       'amount': 4454,
#       'regular_amount': 5599,
#       'currency_id': 'BRL',
#       'exchange_rate_context': 'DEFAULT',
#       'metadata': {'promotion_id': '11034819-MLB1729453817',
#        'promotion_type': 'deal_of_the_day'},
#       'last_updated': '2021-06-24T22:00:05Z'}],
#     'presentation': {'display_currency': 'BRL'},
#     'payment_method_prices': [],
#     'reference_prices': [],
#     'purchase_discounts': []},
#    'sale_price': None,
#    'currency_id': 'BRL',
#    'available_quantity': 882,
#    'sold_quantity': 1713,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2040-11-22T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://www.mercadolivre.com.br/apple-iphone-11-128-gb-branco/p/MLB15149568',
#    'thumbnail': 'http://http2.mlstatic.com/D_821379-MLA46114620180_052021-I.jpg',
#    'thumbnail_id': '821379-MLA46114620180_052021',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 371.17,
#     'rate': 0,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-SP',
#     'state_name': 'São Paulo',
#     'city_id': 'QlItU1BDYWphbWFy',
#     'city_name': 'Cajamar'},
#    'shipping': {'free_shipping': False,
#     'mode': 'me1',
#     'tags': [],
#     'logistic_type': 'default',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-SP', 'name': 'São Paulo'},
#     'city': {'id': 'QlItU1BDYWphbWFy', 'name': 'Cajamar'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'values': [{'id': '9344',
#        'name': 'Apple',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'id': 'BRAND',
#      'value_struct': None,
#      'value_name': 'Apple',
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'name': 'Marca',
#      'value_id': '9344'},
#     {'value_id': '7740544',
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'attribute_group_id': 'OTHERS',
#      'id': 'GPU_MODEL',
#      'name': 'Modelo de GPU',
#      'value_name': 'Apple GPU MP4',
#      'value_struct': None,
#      'values': [{'source': 1,
#        'id': '7740544',
#        'name': 'Apple GPU MP4',
#        'struct': None}]},
#     {'attribute_group_id': 'OTHERS',
#      'name': 'Condição do item',
#      'value_id': '2230284',
#      'value_struct': None,
#      'values': [{'source': 1,
#        'id': '2230284',
#        'name': 'Novo',
#        'struct': None}],
#      'id': 'ITEM_CONDITION',
#      'value_name': 'Novo',
#      'attribute_group_name': 'Outros',
#      'source': 1},
#     {'value_name': 'iPhone',
#      'value_struct': None,
#      'source': 1,
#      'id': 'LINE',
#      'name': 'Linha',
#      'value_id': '58993',
#      'values': [{'struct': None,
#        'source': 1,
#        'id': '58993',
#        'name': 'iPhone'}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros'},
#     {'name': 'Modelo',
#      'value_id': '7739079',
#      'value_struct': None,
#      'values': [{'id': '7739079',
#        'name': 'iPhone 11',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'id': 'MODEL',
#      'value_name': 'iPhone 11',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros'},
#     {'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'name': 'Modelo do processador',
#      'value_id': '7740540',
#      'value_struct': None,
#      'source': 1,
#      'id': 'PROCESSOR_MODEL',
#      'value_name': 'Apple A13 Bionic',
#      'values': [{'id': '7740540',
#        'name': 'Apple A13 Bionic',
#        'struct': None,
#        'source': 1}]},
#     {'value_struct': {'number': 194, 'unit': 'g'},
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'id': 'WEIGHT',
#      'name': 'Peso',
#      'value_id': '2583040',
#      'value_name': '194 g',
#      'values': [{'name': '194 g',
#        'struct': {'number': 194, 'unit': 'g'},
#        'source': 1,
#        'id': '2583040'}]}],
#    'differential_pricing': {'id': 33580182},
#    'original_price': 5599,
#    'category_id': 'MLB1055',
#    'official_store_id': 942,
#    'domain_id': 'MLB-CELLPHONES',
#    'catalog_product_id': 'MLB15149568',
#    'tags': ['deal_of_the_day',
#     'good_quality_picture',
#     'good_quality_thumbnail',
#     'brand_verified',
#     'immediate_payment',
#     'cart_eligible',
#     'shipping_guaranteed',
#     'meli_choice_candidate'],
#    'catalog_listing': True,
#    'use_thumbnail_id': True,
#    'order_backend': 1},
#   {'id': 'MLB1929087758',
#    'site_id': 'MLB',
#    'title': 'Apple iPhone 11 (64 Gb) - Preto',
#    'seller': {'id': 53046290,
#     'permalink': 'http://perfil.mercadolivre.com.br/ABESHOPS',
#     'registration_date': '2008-08-04T23:49:18.000-04:00',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': ['normal',
#      'mshops',
#      'credits_profile',
#      'messages_as_seller',
#      'messages_as_buyer'],
#     'seller_reputation': {'transactions': {'total': 38,
#       'canceled': 2,
#       'period': 'historic',
#       'ratings': {'negative': 0, 'positive': 1, 'neutral': 0},
#       'completed': 36},
#      'power_seller_status': None,
#      'metrics': {'claims': {'rate': 0, 'value': 1, 'period': '365 days'},
#       'delayed_handling_time': {'rate': 0, 'value': 0, 'period': '365 days'},
#       'sales': {'period': '365 days', 'completed': 36},
#       'cancellations': {'rate': 0, 'value': 0, 'period': '365 days'}},
#      'level_id': '5_green'}},
#    'price': 4439,
#    'prices': {'id': 'MLB1929087758',
#     'prices': [{'id': '2',
#       'type': 'standard',
#       'conditions': {'context_restrictions': [],
#        'start_time': None,
#        'end_time': None,
#        'eligible': True},
#       'amount': 4439,
#       'regular_amount': None,
#       'currency_id': 'BRL',
#       'exchange_rate_context': 'DEFAULT',
#       'metadata': {},
#       'last_updated': '2021-06-25T21:50:46Z'}],
#     'presentation': {'display_currency': 'BRL'},
#     'payment_method_prices': [],
#     'reference_prices': [],
#     'purchase_discounts': []},
#    'sale_price': None,
#    'currency_id': 'BRL',
#    'available_quantity': 1,
#    'sold_quantity': 0,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2041-06-20T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://www.mercadolivre.com.br/apple-iphone-11-64-gb-preto/p/MLB15149561',
#    'thumbnail': 'http://http2.mlstatic.com/D_832687-MLA46114578406_052021-I.jpg',
#    'thumbnail_id': '832687-MLA46114578406_052021',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 369.92,
#     'rate': 0,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-SP',
#     'state_name': 'São Paulo',
#     'city_id': 'BR-SP-44',
#     'city_name': 'São Paulo'},
#    'shipping': {'free_shipping': True,
#     'mode': 'me2',
#     'tags': ['mandatory_free_shipping'],
#     'logistic_type': 'drop_off',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-SP', 'name': 'São Paulo'},
#     'city': {'id': 'BR-SP-44', 'name': 'São Paulo'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'name': 'Marca',
#      'source': 1,
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'id': 'BRAND',
#      'value_id': '9344',
#      'value_name': 'Apple',
#      'value_struct': None,
#      'values': [{'id': '9344', 'name': 'Apple', 'struct': None, 'source': 1}]},
#     {'value_name': 'Apple GPU MP4',
#      'values': [{'id': '7740544',
#        'name': 'Apple GPU MP4',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'id': 'GPU_MODEL',
#      'name': 'Modelo de GPU',
#      'value_id': '7740544',
#      'value_struct': None,
#      'source': 1},
#     {'id': 'ITEM_CONDITION',
#      'value_name': 'Novo',
#      'attribute_group_name': 'Outros',
#      'name': 'Condição do item',
#      'value_id': '2230284',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Novo',
#        'struct': None,
#        'source': 7092}],
#      'attribute_group_id': 'OTHERS',
#      'source': 7092},
#     {'name': 'Linha',
#      'value_id': '58993',
#      'value_name': 'iPhone',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'id': 'LINE',
#      'source': 1,
#      'values': [{'id': '58993',
#        'name': 'iPhone',
#        'struct': None,
#        'source': 1}]},
#     {'source': 1,
#      'id': 'MODEL',
#      'value_id': '7739079',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'name': 'Modelo',
#      'value_name': 'iPhone 11',
#      'value_struct': None,
#      'values': [{'id': '7739079',
#        'name': 'iPhone 11',
#        'struct': None,
#        'source': 1}]},
#     {'id': 'PROCESSOR_MODEL',
#      'values': [{'id': '7740540',
#        'name': 'Apple A13 Bionic',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'value_struct': None,
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'name': 'Modelo do processador',
#      'value_id': '7740540',
#      'value_name': 'Apple A13 Bionic'},
#     {'attribute_group_name': 'Outros',
#      'name': 'Peso',
#      'value_id': '2583040',
#      'values': [{'id': '2583040',
#        'name': '194 g',
#        'struct': {'unit': 'g', 'number': 194},
#        'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'source': 1,
#      'id': 'WEIGHT',
#      'value_name': '194 g',
#      'value_struct': {'number': 194, 'unit': 'g'}}],
#    'differential_pricing': {'id': 33580182},
#    'original_price': None,
#    'category_id': 'MLB1055',
#    'official_store_id': None,
#    'domain_id': 'MLB-CELLPHONES',
#    'catalog_product_id': 'MLB15149561',
#    'tags': ['extended_warranty_eligible',
#     'immediate_payment',
#     'cart_eligible',
#     'shipping_guaranteed'],
#    'catalog_listing': True,
#    'use_thumbnail_id': True,
#    'order_backend': 2},
#   {'id': 'MLB1859295006',
#    'site_id': 'MLB',
#    'title': ' iPhone 7 32 Gb Ouro Rosa',
#    'seller': {'id': 577525755,
#     'permalink': 'http://perfil.mercadolivre.com.br/ELIETE+SOLARIS',
#     'registration_date': '2020-08-08T09:30:53.000-04:00',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': ['normal',
#      'credits_profile',
#      'messages_as_seller',
#      'messages_as_buyer'],
#     'seller_reputation': {'transactions': {'total': 52,
#       'canceled': 8,
#       'period': 'historic',
#       'ratings': {'negative': 0, 'positive': 1, 'neutral': 0},
#       'completed': 44},
#      'power_seller_status': None,
#      'metrics': {'claims': {'rate': 0, 'value': 1, 'period': '365 days'},
#       'delayed_handling_time': {'rate': 0.0212,
#        'value': 1,
#        'period': '365 days'},
#       'sales': {'period': '365 days', 'completed': 44},
#       'cancellations': {'rate': 0, 'value': 1, 'period': '365 days'}},
#      'level_id': '5_green'}},
#    'price': 1525,
#    'prices': {'id': 'MLB1859295006',
#     'prices': [{'id': '9',
#       'type': 'standard',
#       'conditions': {'context_restrictions': [],
#        'start_time': None,
#        'end_time': None,
#        'eligible': True},
#       'amount': 1525,
#       'regular_amount': None,
#       'currency_id': 'BRL',
#       'exchange_rate_context': 'DEFAULT',
#       'metadata': {},
#       'last_updated': '2021-06-25T15:56:07Z'}],
#     'presentation': {'display_currency': 'BRL'},
#     'payment_method_prices': [],
#     'reference_prices': [],
#     'purchase_discounts': []},
#    'sale_price': None,
#    'currency_id': 'BRL',
#    'available_quantity': 1,
#    'sold_quantity': 2,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2041-04-13T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://www.mercadolivre.com.br/iphone-7-32-gb-ouro-rosa/p/MLB6240113',
#    'thumbnail': 'http://http2.mlstatic.com/D_665554-MLA43711395476_102020-I.jpg',
#    'thumbnail_id': '665554-MLA43711395476_102020',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 127.08,
#     'rate': 0,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-SP',
#     'state_name': 'São Paulo',
#     'city_id': 'QlItU1BDYXBpdmFyaQ',
#     'city_name': 'Capivari'},
#    'shipping': {'free_shipping': True,
#     'mode': 'me2',
#     'tags': ['mandatory_free_shipping'],
#     'logistic_type': 'drop_off',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-SP', 'name': 'São Paulo'},
#     'city': {'id': 'QlItU1BDYXBpdmFyaQ', 'name': 'Capivari'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'name': 'Marca',
#      'value_id': '9344',
#      'value_name': 'Apple',
#      'values': [{'struct': None, 'source': 1, 'id': '9344', 'name': 'Apple'}],
#      'id': 'BRAND',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 1},
#     {'id': 'GPU_MODEL',
#      'value_name': 'PowerVR Series7XT Plus',
#      'value_struct': None,
#      'values': [{'id': '8010379',
#        'name': 'PowerVR Series7XT Plus',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'name': 'Modelo de GPU',
#      'value_id': '8010379',
#      'attribute_group_id': 'OTHERS'},
#     {'id': 'ITEM_CONDITION',
#      'name': 'Condição do item',
#      'value_id': '2230284',
#      'value_name': 'Novo',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 6808261514773724,
#      'values': [{'source': 6808261514773724,
#        'id': '2230284',
#        'name': 'Novo',
#        'struct': None}]},
#     {'values': [{'struct': None,
#        'source': 1,
#        'id': '58993',
#        'name': 'iPhone'}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'name': 'Linha',
#      'value_id': '58993',
#      'value_name': 'iPhone',
#      'id': 'LINE',
#      'value_struct': None,
#      'source': 1},
#     {'values': [{'id': '312155',
#        'name': 'iPhone 7',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'attribute_group_id': 'OTHERS',
#      'id': 'MODEL',
#      'name': 'Modelo',
#      'value_id': '312155',
#      'value_name': 'iPhone 7',
#      'value_struct': None},
#     {'attribute_group_id': 'OTHERS',
#      'name': 'Modelo do processador',
#      'value_id': '6946002',
#      'value_name': 'Apple A10 Fusion',
#      'value_struct': None,
#      'values': [{'id': '6946002',
#        'name': 'Apple A10 Fusion',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'id': 'PROCESSOR_MODEL'},
#     {'source': 1,
#      'name': 'Peso',
#      'value_name': '138 g',
#      'value_struct': {'number': 138, 'unit': 'g'},
#      'attribute_group_name': 'Outros',
#      'id': 'WEIGHT',
#      'value_id': '522902',
#      'values': [{'struct': {'unit': 'g', 'number': 138},
#        'source': 1,
#        'id': '522902',
#        'name': '138 g'}],
#      'attribute_group_id': 'OTHERS'}],
#    'differential_pricing': {'id': 33580182},
#    'original_price': None,
#    'category_id': 'MLB1055',
#    'official_store_id': None,
#    'domain_id': 'MLB-CELLPHONES',
#    'catalog_product_id': 'MLB6240113',
#    'tags': ['loyalty_discount_eligible',
#     'extended_warranty_eligible',
#     'good_quality_picture',
#     'immediate_payment',
#     'cart_eligible',
#     'meli_choice_candidate'],
#    'catalog_listing': True,
#    'use_thumbnail_id': True,
#    'order_backend': 3},
#   {'id': 'MLB1924083629',
#    'site_id': 'MLB',
#    'title': ' iPhone XR 64 Gb Branco',
#    'seller': {'id': 36583886,
#     'permalink': 'http://perfil.mercadolivre.com.br/UPFONE',
#     'registration_date': '2010-11-04T11:50:42.000-04:00',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': ['normal',
#      'credits_priority_3',
#      'credits_profile',
#      'messages_as_seller',
#      'messages_as_buyer'],
#     'seller_reputation': {'transactions': {'total': 5391,
#       'canceled': 507,
#       'period': 'historic',
#       'ratings': {'negative': 0.11, 'positive': 0.85, 'neutral': 0.04},
#       'completed': 4884},
#      'power_seller_status': 'platinum',
#      'metrics': {'claims': {'rate': 0.0157, 'value': 20, 'period': '60 days'},
#       'delayed_handling_time': {'rate': 0.0016,
#        'value': 2,
#        'period': '60 days'},
#       'sales': {'period': '60 days', 'completed': 1169},
#       'cancellations': {'rate': 0, 'value': 1, 'period': '60 days'}},
#      'level_id': '5_green'}},
#    'price': 3642,
#    'prices': {'id': 'MLB1924083629',
#     'prices': [{'id': '3',
#       'type': 'standard',
#       'conditions': {'context_restrictions': [],
#        'start_time': None,
#        'end_time': None,
#        'eligible': True},
#       'amount': 3642,
#       'regular_amount': None,
#       'currency_id': 'BRL',
#       'exchange_rate_context': 'DEFAULT',
#       'metadata': {},
#       'last_updated': '2021-06-23T22:04:47Z'}],
#     'presentation': {'display_currency': 'BRL'},
#     'payment_method_prices': [],
#     'reference_prices': [],
#     'purchase_discounts': []},
#    'sale_price': None,
#    'currency_id': 'BRL',
#    'available_quantity': 1,
#    'sold_quantity': 12,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2041-06-16T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://www.mercadolivre.com.br/iphone-xr-64-gb-branco/p/MLB12866679',
#    'thumbnail': 'http://http2.mlstatic.com/D_849300-MLA43693785678_102020-I.jpg',
#    'thumbnail_id': '849300-MLA43693785678_102020',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 303.5,
#     'rate': 0,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-SP',
#     'state_name': 'São Paulo',
#     'city_id': 'BR-SP-31',
#     'city_name': 'Osasco'},
#    'shipping': {'free_shipping': True,
#     'mode': 'me2',
#     'tags': ['self_service_in', 'mandatory_free_shipping'],
#     'logistic_type': 'xd_drop_off',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-SP', 'name': 'São Paulo'},
#     'city': {'id': 'BR-SP-31', 'name': 'Osasco'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'values': [{'name': 'Apple',
#        'struct': None,
#        'source': 1,
#        'id': '9344'}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'id': 'BRAND',
#      'value_id': '9344',
#      'value_name': 'Apple',
#      'name': 'Marca',
#      'value_struct': None},
#     {'value_struct': None,
#      'name': 'Condição do item',
#      'value_id': '2230284',
#      'value_name': 'Novo',
#      'values': [{'name': 'Novo',
#        'struct': None,
#        'source': 2860837171021627,
#        'id': '2230284'}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 2860837171021627,
#      'id': 'ITEM_CONDITION'},
#     {'name': 'Linha',
#      'value_name': 'iPhone',
#      'source': 1,
#      'id': 'LINE',
#      'value_id': '58993',
#      'value_struct': None,
#      'values': [{'struct': None,
#        'source': 1,
#        'id': '58993',
#        'name': 'iPhone'}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros'},
#     {'attribute_group_name': 'Outros',
#      'id': 'MODEL',
#      'value_struct': None,
#      'value_name': 'iPhone XR',
#      'values': [{'source': 1,
#        'id': '5414260',
#        'name': 'iPhone XR',
#        'struct': None}],
#      'attribute_group_id': 'OTHERS',
#      'source': 1,
#      'name': 'Modelo',
#      'value_id': '5414260'},
#     {'value_id': '6927771',
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'id': 'PROCESSOR_MODEL',
#      'name': 'Modelo do processador',
#      'value_name': 'Apple A12 Bionic',
#      'value_struct': None,
#      'values': [{'id': '6927771',
#        'name': 'Apple A12 Bionic',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS'},
#     {'name': 'Peso',
#      'value_id': '2583040',
#      'value_struct': {'number': 194, 'unit': 'g'},
#      'values': [{'id': '2583040',
#        'name': '194 g',
#        'struct': {'unit': 'g', 'number': 194},
#        'source': 1}],
#      'source': 1,
#      'id': 'WEIGHT',
#      'value_name': '194 g',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros'}],
#    'differential_pricing': {'id': 33580182},
#    'original_price': None,
#    'category_id': 'MLB1055',
#    'official_store_id': None,
#    'domain_id': 'MLB-CELLPHONES',
#    'catalog_product_id': 'MLB12866679',
#    'tags': ['extended_warranty_eligible',
#     'good_quality_picture',
#     'good_quality_thumbnail',
#     'loyalty_discount_eligible',
#     'immediate_payment',
#     'cart_eligible',
#     'shipping_guaranteed',
#     'meli_choice_candidate'],
#    'catalog_listing': True,
#    'use_thumbnail_id': True,
#    'order_backend': 4},
#   {'id': 'MLB1857350525',
#    'site_id': 'MLB',
#    'title': ' iPhone 8 Plus 64 Gb Prateado',
#    'seller': {'id': 418784891,
#     'permalink': 'http://perfil.mercadolivre.com.br/YESSHOPONLINE',
#     'registration_date': '2019-03-21T11:10:53.000-04:00',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': ['normal', 'messages_as_seller', 'messages_as_buyer'],
#     'seller_reputation': {'transactions': {'total': 7570,
#       'canceled': 901,
#       'period': 'historic',
#       'ratings': {'negative': 0.03, 'positive': 0.96, 'neutral': 0.01},
#       'completed': 6669},
#      'power_seller_status': None,
#      'metrics': {'claims': {'rate': 0.0285, 'value': 35, 'period': '60 days'},
#       'delayed_handling_time': {'rate': 0.0119,
#        'value': 13,
#        'period': '60 days'},
#       'sales': {'period': '60 days', 'completed': 1047},
#       'cancellations': {'rate': 0.0081, 'value': 10, 'period': '60 days'}},
#      'level_id': '5_green'}},
#    'price': 2822,
#    'prices': {'id': 'MLB1857350525',
#     'prices': [{'id': '11',
#       'type': 'standard',
#       'conditions': {'context_restrictions': [],
#        'start_time': None,
#        'end_time': None,
#        'eligible': True},
#       'amount': 2822,
#       'regular_amount': None,
#       'currency_id': 'BRL',
#       'exchange_rate_context': 'DEFAULT',
#       'metadata': {},
#       'last_updated': '2021-06-25T15:12:51Z'}],
#     'presentation': {'display_currency': 'BRL'},
#     'payment_method_prices': [],
#     'reference_prices': [],
#     'purchase_discounts': []},
#    'sale_price': None,
#    'currency_id': 'BRL',
#    'available_quantity': 12,
#    'sold_quantity': 29,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2041-04-10T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://www.mercadolivre.com.br/iphone-8-plus-64-gb-prateado/p/MLB8752452',
#    'thumbnail': 'http://http2.mlstatic.com/D_701783-MLA43711395860_102020-I.jpg',
#    'thumbnail_id': '701783-MLA43711395860_102020',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 235.17,
#     'rate': 0,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-PR',
#     'state_name': 'Paraná',
#     'city_id': 'TUxCQ0NVUjYyZmY1',
#     'city_name': 'Curitiba'},
#    'shipping': {'free_shipping': True,
#     'mode': 'me2',
#     'tags': ['mandatory_free_shipping'],
#     'logistic_type': 'cross_docking',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-PR', 'name': 'Paraná'},
#     'city': {'id': 'TUxCQ0NVUjYyZmY1', 'name': 'Curitiba'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'id': 'BRAND',
#      'value_id': '9344',
#      'value_name': 'Apple',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'name': 'Marca',
#      'values': [{'id': '9344', 'name': 'Apple', 'struct': None, 'source': 1}],
#      'attribute_group_name': 'Outros',
#      'source': 1},
#     {'attribute_group_id': 'OTHERS',
#      'value_id': '7741027',
#      'value_struct': None,
#      'values': [{'struct': None,
#        'source': 1,
#        'id': '7741027',
#        'name': 'Apple GPU'}],
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'id': 'GPU_MODEL',
#      'name': 'Modelo de GPU',
#      'value_name': 'Apple GPU'},
#     {'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 8021611602487823,
#      'id': 'ITEM_CONDITION',
#      'value_name': 'Novo',
#      'value_struct': None,
#      'values': [{'id': '2230284',
#        'name': 'Novo',
#        'struct': None,
#        'source': 8021611602487823}],
#      'name': 'Condição do item',
#      'value_id': '2230284'},
#     {'name': 'Linha',
#      'value_name': 'iPhone',
#      'value_struct': None,
#      'attribute_group_name': 'Outros',
#      'id': 'LINE',
#      'values': [{'id': '58993',
#        'name': 'iPhone',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'source': 1,
#      'value_id': '58993'},
#     {'id': 'MODEL',
#      'value_struct': None,
#      'values': [{'struct': None,
#        'source': 1,
#        'id': '2244673',
#        'name': 'iPhone 8 Plus'}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'name': 'Modelo',
#      'value_id': '2244673',
#      'value_name': 'iPhone 8 Plus'},
#     {'attribute_group_id': 'OTHERS',
#      'source': 1,
#      'id': 'PROCESSOR_MODEL',
#      'value_name': 'Apple A11 Bionic',
#      'value_struct': None,
#      'values': [{'id': '6936434',
#        'name': 'Apple A11 Bionic',
#        'struct': None,
#        'source': 1}],
#      'name': 'Modelo do processador',
#      'value_id': '6936434',
#      'attribute_group_name': 'Outros'},
#     {'source': 1,
#      'id': 'WEIGHT',
#      'name': 'Peso',
#      'values': [{'name': '202 g',
#        'struct': {'number': 202, 'unit': 'g'},
#        'source': 1,
#        'id': '2263677'}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'value_id': '2263677',
#      'value_name': '202 g',
#      'value_struct': {'number': 202, 'unit': 'g'}}],
#    'differential_pricing': {'id': 33580182},
#    'original_price': None,
#    'category_id': 'MLB1055',
#    'official_store_id': None,
#    'domain_id': 'MLB-CELLPHONES',
#    'catalog_product_id': 'MLB8752452',
#    'tags': ['catalog_boost',
#     'extended_warranty_eligible',
#     'good_quality_picture',
#     'good_quality_thumbnail',
#     'loyalty_discount_eligible',
#     'immediate_payment',
#     'cart_eligible',
#     'shipping_guaranteed'],
#    'catalog_listing': True,
#    'use_thumbnail_id': True,
#    'order_backend': 5},
#   {'id': 'MLB1755610685',
#    'site_id': 'MLB',
#    'title': 'Apple iPhone 12 Pro Max (128 Gb) - Prateado',
#    'seller': {'id': 54486513,
#     'permalink': 'http://perfil.mercadolivre.com.br/ROCHAVARIEDADESGO',
#     'registration_date': '2008-09-17T19:14:47.000-04:00',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': ['normal',
#      'credits_profile',
#      'mshops',
#      'messages_as_seller',
#      'messages_as_buyer'],
#     'seller_reputation': {'transactions': {'total': 1783,
#       'canceled': 211,
#       'period': 'historic',
#       'ratings': {'negative': 0, 'positive': 1, 'neutral': 0},
#       'completed': 1572},
#      'power_seller_status': 'gold',
#      'metrics': {'claims': {'rate': 0.0144, 'value': 3, 'period': '60 days'},
#       'delayed_handling_time': {'rate': 0.0937,
#        'value': 18,
#        'period': '60 days'},
#       'sales': {'period': '60 days', 'completed': 194},
#       'cancellations': {'rate': 0.0144, 'value': 3, 'period': '60 days'}},
#      'level_id': '5_green'}},
#    'price': 8790,
#    'prices': {'id': 'MLB1755610685',
#     'prices': [{'id': '12',
#       'type': 'standard',
#       'conditions': {'context_restrictions': [],
#        'start_time': None,
#        'end_time': None,
#        'eligible': True},
#       'amount': 8790,
#       'regular_amount': None,
#       'currency_id': 'BRL',
#       'exchange_rate_context': 'DEFAULT',
#       'metadata': {},
#       'last_updated': '2021-06-23T21:57:54Z'}],
#     'presentation': {'display_currency': 'BRL'},
#     'payment_method_prices': [],
#     'reference_prices': [],
#     'purchase_discounts': []},
#    'sale_price': None,
#    'currency_id': 'BRL',
#    'available_quantity': 4,
#    'sold_quantity': 1,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2040-12-30T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://www.mercadolivre.com.br/apple-iphone-12-pro-max-128-gb-prateado/p/MLB16163693',
#    'thumbnail': 'http://http2.mlstatic.com/D_765496-MLA46093155208_052021-I.jpg',
#    'thumbnail_id': '765496-MLA46093155208_052021',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 732.5,
#     'rate': 0,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-GO',
#     'state_name': 'Goiás',
#     'city_id': 'TUxR29p4m5pYQ',
#     'city_name': 'Goiânia'},
#    'shipping': {'free_shipping': True,
#     'mode': 'me2',
#     'tags': ['mandatory_free_shipping'],
#     'logistic_type': 'drop_off',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-GO', 'name': 'Goiás'},
#     'city': {'id': 'TUxR29p4m5pYQ', 'name': 'Goiânia'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'value_id': '9344',
#      'value_name': 'Apple',
#      'values': [{'name': 'Apple', 'struct': None, 'source': 1, 'id': '9344'}],
#      'attribute_group_id': 'OTHERS',
#      'id': 'BRAND',
#      'value_struct': None,
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'name': 'Marca'},
#     {'values': [{'id': '7741027',
#        'name': 'Apple GPU',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_name': 'Outros',
#      'id': 'GPU_MODEL',
#      'value_id': '7741027',
#      'value_name': 'Apple GPU',
#      'source': 1,
#      'name': 'Modelo de GPU',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS'},
#     {'id': 'ITEM_CONDITION',
#      'values': [{'id': '2230284',
#        'name': 'Novo',
#        'struct': None,
#        'source': 2860837171021627}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 2860837171021627,
#      'name': 'Condição do item',
#      'value_id': '2230284',
#      'value_name': 'Novo',
#      'value_struct': None},
#     {'id': 'LINE',
#      'values': [{'name': 'iPhone',
#        'struct': None,
#        'source': 1,
#        'id': '58993'}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'name': 'Linha',
#      'value_id': '58993',
#      'value_name': 'iPhone',
#      'value_struct': None},
#     {'name': 'Modelo',
#      'value_struct': None,
#      'values': [{'source': 1,
#        'id': '9081385',
#        'name': 'iPhone 12 Pro Max',
#        'struct': None}],
#      'attribute_group_id': 'OTHERS',
#      'source': 1,
#      'id': 'MODEL',
#      'value_id': '9081385',
#      'value_name': 'iPhone 12 Pro Max',
#      'attribute_group_name': 'Outros'},
#     {'value_name': 'Apple A14 Bionic',
#      'value_struct': None,
#      'values': [{'id': '9094177',
#        'name': 'Apple A14 Bionic',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_name': 'Outros',
#      'id': 'PROCESSOR_MODEL',
#      'name': 'Modelo do processador',
#      'value_id': '9094177',
#      'attribute_group_id': 'OTHERS',
#      'source': 1},
#     {'attribute_group_id': 'OTHERS',
#      'source': 1,
#      'name': 'Peso',
#      'value_id': '462004',
#      'value_struct': {'number': 228, 'unit': 'g'},
#      'values': [{'id': '462004',
#        'name': '228 g',
#        'struct': {'number': 228, 'unit': 'g'},
#        'source': 1}],
#      'attribute_group_name': 'Outros',
#      'id': 'WEIGHT',
#      'value_name': '228 g'}],
#    'differential_pricing': {'id': 33580182},
#    'original_price': None,
#    'category_id': 'MLB1055',
#    'official_store_id': None,
#    'domain_id': 'MLB-CELLPHONES',
#    'catalog_product_id': 'MLB16163693',
#    'tags': ['brand_verified',
#     'good_quality_picture',
#     'loyalty_discount_eligible',
#     'immediate_payment',
#     'cart_eligible',
#     'shipping_guaranteed'],
#    'catalog_listing': True,
#    'use_thumbnail_id': True,
#    'order_backend': 6},
#   {'id': 'MLB1927968106',
#    'site_id': 'MLB',
#    'title': ' iPhone 8 64 Gb Cinza-espacial',
#    'seller': {'id': 131333084,
#     'permalink': 'http://perfil.mercadolivre.com.br/EXPRESS+SHOP-E',
#     'registration_date': '2013-01-03T22:34:02.000-04:00',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': ['normal',
#      'credits_profile',
#      'mshops',
#      'messages_as_seller',
#      'messages_as_buyer'],
#     'seller_reputation': {'transactions': {'total': 23,
#       'canceled': 1,
#       'period': 'historic',
#       'ratings': {'negative': 0, 'positive': 1, 'neutral': 0},
#       'completed': 22},
#      'power_seller_status': None,
#      'metrics': {'claims': {'rate': 0, 'value': 0, 'period': '365 days'},
#       'delayed_handling_time': {'rate': 0, 'value': 0, 'period': '365 days'},
#       'sales': {'period': '365 days', 'completed': 22},
#       'cancellations': {'rate': 0, 'value': 0, 'period': '365 days'}},
#      'level_id': '5_green'}},
#    'price': 2049,
#    'prices': {'id': 'MLB1927968106',
#     'prices': [{'id': '2',
#       'type': 'standard',
#       'conditions': {'context_restrictions': [],
#        'start_time': None,
#        'end_time': None,
#        'eligible': True},
#       'amount': 2049,
#       'regular_amount': None,
#       'currency_id': 'BRL',
#       'exchange_rate_context': 'DEFAULT',
#       'metadata': {},
#       'last_updated': '2021-06-25T15:41:21Z'}],
#     'presentation': {'display_currency': 'BRL'},
#     'payment_method_prices': [],
#     'reference_prices': [],
#     'purchase_discounts': []},
#    'sale_price': None,
#    'currency_id': 'BRL',
#    'available_quantity': 1,
#    'sold_quantity': 0,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_special',
#    'stop_time': '2041-06-19T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://www.mercadolivre.com.br/iphone-8-64-gb-cinza-espacial/p/MLB8752432',
#    'thumbnail': 'http://http2.mlstatic.com/D_819468-MLA43694219099_102020-I.jpg',
#    'thumbnail_id': '819468-MLA43694219099_102020',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 194.64,
#     'rate': 13.99,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-ES',
#     'state_name': 'Espírito Santo',
#     'city_id': 'TUxCQ1ZJTGU5YTdl',
#     'city_name': 'Vila Velha'},
#    'shipping': {'free_shipping': True,
#     'mode': 'me2',
#     'tags': ['mandatory_free_shipping'],
#     'logistic_type': 'drop_off',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-ES', 'name': 'Espírito Santo'},
#     'city': {'id': 'TUxCQ1ZJTGU5YTdl', 'name': 'Vila Velha'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'values': [{'source': 1,
#        'id': '9344',
#        'name': 'Apple',
#        'struct': None}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'name': 'Marca',
#      'value_id': '9344',
#      'value_name': 'Apple',
#      'id': 'BRAND',
#      'value_struct': None,
#      'source': 1},
#     {'value_id': '2230284',
#      'values': [{'id': '2230284',
#        'name': 'Novo',
#        'struct': None,
#        'source': 2860837171021627}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'id': 'ITEM_CONDITION',
#      'name': 'Condição do item',
#      'source': 2860837171021627,
#      'value_name': 'Novo',
#      'value_struct': None},
#     {'value_name': 'iPhone',
#      'attribute_group_name': 'Outros',
#      'attribute_group_id': 'OTHERS',
#      'source': 1,
#      'id': 'LINE',
#      'name': 'Linha',
#      'value_id': '58993',
#      'value_struct': None,
#      'values': [{'id': '58993',
#        'name': 'iPhone',
#        'struct': None,
#        'source': 1}]},
#     {'id': 'MODEL',
#      'name': 'Modelo',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'value_id': '2244670',
#      'value_name': 'iPhone 8',
#      'value_struct': None,
#      'values': [{'id': '2244670',
#        'name': 'iPhone 8',
#        'struct': None,
#        'source': 1}]},
#     {'id': 'PROCESSOR_MODEL',
#      'name': 'Modelo do processador',
#      'value_name': 'Apple A11 Bionic',
#      'values': [{'id': '6936434',
#        'name': 'Apple A11 Bionic',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'value_id': '6936434',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS'},
#     {'value_id': '6861161',
#      'value_name': '148 g',
#      'values': [{'name': '148 g',
#        'struct': {'number': 148, 'unit': 'g'},
#        'source': 1,
#        'id': '6861161'}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'id': 'WEIGHT',
#      'name': 'Peso',
#      'value_struct': {'unit': 'g', 'number': 148},
#      'source': 1}],
#    'original_price': None,
#    'category_id': 'MLB1055',
#    'official_store_id': None,
#    'domain_id': 'MLB-CELLPHONES',
#    'catalog_product_id': 'MLB8752432',
#    'tags': ['extended_warranty_eligible',
#     'good_quality_picture',
#     'immediate_payment',
#     'cart_eligible'],
#    'catalog_listing': True,
#    'use_thumbnail_id': True,
#    'order_backend': 7},
#   {'id': 'MLB1925505282',
#    'site_id': 'MLB',
#    'title': 'Apple iPhone 12 (64 Gb) - Branco',
#    'seller': {'id': 708615982,
#     'permalink': 'http://perfil.mercadolivre.com.br/JS+MOBILESP',
#     'registration_date': '2021-01-30T06:35:07.000-04:00',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': ['normal', 'messages_as_seller', 'messages_as_buyer'],
#     'seller_reputation': {'transactions': {'total': 73,
#       'canceled': 3,
#       'period': 'historic',
#       'ratings': {'negative': 0, 'positive': 1, 'neutral': 0},
#       'completed': 70},
#      'power_seller_status': None,
#      'metrics': {'claims': {'rate': 0, 'value': 0, 'period': '365 days'},
#       'delayed_handling_time': {'rate': 0.0307,
#        'value': 2,
#        'period': '365 days'},
#       'sales': {'period': '365 days', 'completed': 70},
#       'cancellations': {'rate': 0, 'value': 0, 'period': '365 days'}},
#      'level_id': '5_green'}},
#    'price': 6395,
#    'prices': {'id': 'MLB1925505282',
#     'prices': [{'id': '3',
#       'type': 'standard',
#       'conditions': {'context_restrictions': [],
#        'start_time': None,
#        'end_time': None,
#        'eligible': True},
#       'amount': 6395,
#       'regular_amount': None,
#       'currency_id': 'BRL',
#       'exchange_rate_context': 'DEFAULT',
#       'metadata': {},
#       'last_updated': '2021-06-23T14:18:05Z'}],
#     'presentation': {'display_currency': 'BRL'},
#     'payment_method_prices': [],
#     'reference_prices': [],
#     'purchase_discounts': []},
#    'sale_price': None,
#    'currency_id': 'BRL',
#    'available_quantity': 1,
#    'sold_quantity': 0,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2041-06-17T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://www.mercadolivre.com.br/apple-iphone-12-64-gb-branco/p/MLB16163647',
#    'thumbnail': 'http://http2.mlstatic.com/D_779793-MLA46082237487_052021-I.jpg',
#    'thumbnail_id': '779793-MLA46082237487_052021',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 532.92,
#     'rate': 0,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-SP',
#     'state_name': 'São Paulo',
#     'city_id': 'BR-SP-70',
#     'city_name': 'Araraquara'},
#    'shipping': {'free_shipping': True,
#     'mode': 'me2',
#     'tags': ['mandatory_free_shipping'],
#     'logistic_type': 'xd_drop_off',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-SP', 'name': 'São Paulo'},
#     'city': {'id': 'BR-SP-70', 'name': 'Araraquara'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'source': 1,
#      'value_id': '9344',
#      'value_name': 'Apple',
#      'value_struct': None,
#      'attribute_group_name': 'Outros',
#      'id': 'BRAND',
#      'name': 'Marca',
#      'values': [{'id': '9344', 'name': 'Apple', 'struct': None, 'source': 1}],
#      'attribute_group_id': 'OTHERS'},
#     {'value_name': 'Novo',
#      'value_struct': None,
#      'source': 3045741222775799,
#      'id': 'ITEM_CONDITION',
#      'name': 'Condição do item',
#      'value_id': '2230284',
#      'values': [{'struct': None,
#        'source': 3045741222775799,
#        'id': '2230284',
#        'name': 'Novo'}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros'},
#     {'id': 'LINE',
#      'attribute_group_id': 'OTHERS',
#      'source': 1,
#      'value_struct': None,
#      'values': [{'name': 'iPhone',
#        'struct': None,
#        'source': 1,
#        'id': '58993'}],
#      'attribute_group_name': 'Outros',
#      'name': 'Linha',
#      'value_id': '58993',
#      'value_name': 'iPhone'},
#     {'value_id': '9081382',
#      'value_name': 'iPhone 12',
#      'values': [{'id': '9081382',
#        'name': 'iPhone 12',
#        'struct': None,
#        'source': 1}],
#      'source': 1,
#      'id': 'MODEL',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'name': 'Modelo'},
#     {'id': 'PROCESSOR_MODEL',
#      'values': [{'source': 1,
#        'id': '9094177',
#        'name': 'Apple A14 Bionic',
#        'struct': None}],
#      'source': 1,
#      'name': 'Modelo do processador',
#      'value_id': '9094177',
#      'value_name': 'Apple A14 Bionic',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros'}],
#    'differential_pricing': {'id': 33580182},
#    'original_price': None,
#    'category_id': 'MLB1055',
#    'official_store_id': None,
#    'domain_id': 'MLB-CELLPHONES',
#    'catalog_product_id': 'MLB16163647',
#    'tags': ['good_quality_picture',
#     'immediate_payment',
#     'cart_eligible',
#     'shipping_guaranteed',
#     'meli_choice_candidate'],
#    'catalog_listing': True,
#    'use_thumbnail_id': True,
#    'order_backend': 8},
#   {'id': 'MLB1929176710',
#    'site_id': 'MLB',
#    'title': 'Apple iPhone 12 Pro Max (256 Gb) - Grafite',
#    'seller': {'id': 681521977,
#     'permalink': 'http://perfil.mercadolivre.com.br/CONECTAAUTOPARTS',
#     'registration_date': '2020-12-02T12:17:24.000-04:00',
#     'car_dealer': False,
#     'real_estate_agency': False,
#     'tags': ['normal', 'mshops', 'messages_as_seller'],
#     'seller_reputation': {'transactions': {'total': 34,
#       'canceled': 3,
#       'period': 'historic',
#       'ratings': {'negative': 0, 'positive': 1, 'neutral': 0},
#       'completed': 31},
#      'power_seller_status': None,
#      'metrics': {'claims': {'rate': 0, 'value': 0, 'period': '365 days'},
#       'delayed_handling_time': {'rate': 0, 'value': 0, 'period': '365 days'},
#       'sales': {'period': '365 days', 'completed': 31},
#       'cancellations': {'rate': 0, 'value': 0, 'period': '365 days'}},
#      'level_id': '5_green'}},
#    'price': 9100,
#    'prices': {'id': 'MLB1929176710',
#     'prices': [{'id': '2',
#       'type': 'standard',
#       'conditions': {'context_restrictions': [],
#        'start_time': None,
#        'end_time': None,
#        'eligible': True},
#       'amount': 9100,
#       'regular_amount': None,
#       'currency_id': 'BRL',
#       'exchange_rate_context': 'DEFAULT',
#       'metadata': {},
#       'last_updated': '2021-06-26T00:56:03Z'}],
#     'presentation': {'display_currency': 'BRL'},
#     'payment_method_prices': [],
#     'reference_prices': [],
#     'purchase_discounts': []},
#    'sale_price': None,
#    'currency_id': 'BRL',
#    'available_quantity': 1,
#    'sold_quantity': 0,
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2041-06-21T00:54:17.000Z',
#    'condition': 'new',
#    'permalink': 'https://www.mercadolivre.com.br/apple-iphone-12-pro-max-256-gb-grafite/p/MLB16163696',
#    'thumbnail': 'http://http2.mlstatic.com/D_792396-MLA46093213172_052021-I.jpg',
#    'thumbnail_id': '792396-MLA46093213172_052021',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 758.33,
#     'rate': 0,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-PR',
#     'state_name': 'Paraná',
#     'city_id': 'TUxCQ0NBU2NiZTll',
#     'city_name': 'Cascavel'},
#    'shipping': {'free_shipping': True,
#     'mode': 'me2',
#     'tags': ['mandatory_free_shipping'],
#     'logistic_type': 'drop_off',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-PR', 'name': 'Paraná'},
#     'city': {'id': 'TUxCQ0NBU2NiZTll', 'name': 'Cascavel'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'value_id': '9344',
#      'value_name': 'Apple',
#      'values': [{'struct': None, 'source': 1, 'id': '9344', 'name': 'Apple'}],
#      'id': 'BRAND',
#      'name': 'Marca',
#      'attribute_group_name': 'Outros',
#      'source': 1,
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS'},
#     {'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'name': 'Modelo de GPU',
#      'value_id': '7741027',
#      'value_name': 'Apple GPU',
#      'values': [{'id': '7741027',
#        'name': 'Apple GPU',
#        'struct': None,
#        'source': 1}],
#      'id': 'GPU_MODEL',
#      'value_struct': None,
#      'source': 1},
#     {'attribute_group_id': 'OTHERS',
#      'source': 2860837171021627,
#      'value_name': 'Novo',
#      'values': [{'struct': None,
#        'source': 2860837171021627,
#        'id': '2230284',
#        'name': 'Novo'}],
#      'value_id': '2230284',
#      'value_struct': None,
#      'attribute_group_name': 'Outros',
#      'id': 'ITEM_CONDITION',
#      'name': 'Condição do item'},
#     {'name': 'Linha',
#      'value_id': '58993',
#      'value_struct': None,
#      'values': [{'id': '58993',
#        'name': 'iPhone',
#        'struct': None,
#        'source': 1}],
#      'attribute_group_id': 'OTHERS',
#      'source': 1,
#      'id': 'LINE',
#      'value_name': 'iPhone',
#      'attribute_group_name': 'Outros'},
# ...
#    'buying_mode': 'buy_it_now',
#    'listing_type_id': 'gold_pro',
#    'stop_time': '2040-05-13T04:00:00.000Z',
#    'condition': 'new',
#    'permalink': 'https://produto.mercadolivre.com.br/MLB-1527524183-iphone-8-64gb-vitrine-apple-tela-47-em-12x-sem-juros-_JM',
#    'thumbnail': 'http://http2.mlstatic.com/D_676727-MLA41314839082_042020-O.jpg',
#    'thumbnail_id': '676727-MLA41314839082_042020',
#    'accepts_mercadopago': True,
#    'installments': {'quantity': 12,
#     'amount': 174.83,
#     'rate': 0,
#     'currency_id': 'BRL'},
#    'address': {'state_id': 'BR-SP',
#     'state_name': 'São Paulo',
#     'city_id': 'BR-SP-44',
#     'city_name': 'São Paulo'},
#    'shipping': {'free_shipping': True,
#     'mode': 'me2',
#     'tags': ['self_service_in', 'mandatory_free_shipping'],
#     'logistic_type': 'xd_drop_off',
#     'store_pick_up': False},
#    'seller_address': {'id': '',
#     'comment': '',
#     'address_line': '',
#     'zip_code': '',
#     'country': {'id': 'BR', 'name': 'Brasil'},
#     'state': {'id': 'BR-SP', 'name': 'São Paulo'},
#     'city': {'id': 'BR-SP-44', 'name': 'São Paulo'},
#     'latitude': '',
#     'longitude': ''},
#    'attributes': [{'name': 'Marca',
#      'value_id': '9344',
#      'value_name': 'Apple',
#      'source': 6808261514773724,
#      'id': 'BRAND',
#      'value_struct': None,
#      'values': [{'source': 6808261514773724,
#        'id': '9344',
#        'name': 'Apple',
#        'struct': None}],
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros'},
#     {'name': 'Condição do item',
#      'attribute_group_name': 'Outros',
#      'source': 6808261514773724,
#      'id': 'ITEM_CONDITION',
#      'value_id': '2230284',
#      'value_name': 'Novo',
#      'value_struct': None,
#      'values': [{'name': 'Novo',
#        'struct': None,
#        'source': 6808261514773724,
#        'id': '2230284'}],
#      'attribute_group_id': 'OTHERS'},
#     {'value_id': '58993',
#      'value_name': 'iPhone',
#      'value_struct': None,
#      'attribute_group_id': 'OTHERS',
#      'source': 6808261514773724,
#      'id': 'LINE',
#      'values': [{'id': '58993',
#        'name': 'iPhone',
#        'struct': None,
#        'source': 6808261514773724}],
#      'attribute_group_name': 'Outros',
#      'name': 'Linha'},
#     {'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'id': 'MODEL',
#      'value_id': '2244670',
#      'value_name': 'iPhone 8',
#      'source': 6808261514773724,
#      'name': 'Modelo',
#      'value_struct': None,
#      'values': [{'id': '2244670',
#        'name': 'iPhone 8',
#        'struct': None,
#        'source': 6808261514773724}]},
#     {'value_id': '6936434',
#      'value_name': 'Apple A11 Bionic',
#      'attribute_group_id': 'OTHERS',
#      'attribute_group_name': 'Outros',
#      'source': 6808261514773724,
#      'id': 'PROCESSOR_MODEL',
#      'name': 'Modelo do processador',
#      'value_struct': None,
#      'values': [{'id': '6936434',
#        'name': 'Apple A11 Bionic',
#        'struct': None,
#        'source': 6808261514773724}]},
#     {'value_id': '6861161',
#      'attribute_group_name': 'Outros',
#      'id': 'WEIGHT',
#      'name': 'Peso',
#      'value_name': '148 g',
#      'value_struct': {'number': 148, 'unit': 'g'},
#      'values': [{'source': 6808261514773724,
#        'id': '6861161',
#        'name': '148 g',
#        'struct': {'number': 148, 'unit': 'g'}}],
#      'attribute_group_id': 'OTHERS',
#      'source': 6808261514773724}],
#    'differential_pricing': {'id': 33580182},
#    'original_price': None,
#    'category_id': 'MLB1055',
#    'official_store_id': None,
#    'domain_id': 'MLB-CELLPHONES',
#    'catalog_product_id': 'MLB8752429',
#    'tags': ['brand_verified',
#     'extended_warranty_eligible',
#     'good_quality_picture',
#     'good_quality_thumbnail',
#     'loyalty_discount_eligible',
#     'immediate_payment',
#     'cart_eligible',
#     'shipping_guaranteed',
#     'best_seller_candidate'],
#    'order_backend': 50,
#    'use_thumbnail_id': False}],
#  'secondary_results': [],
#  'related_results': [],
#  'sort': {'id': 'relevance', 'name': 'Mais relevantes'},
#  'available_sorts': [{'id': 'price_asc', 'name': 'Menor preço'},
#   {'id': 'price_desc', 'name': 'Maior preço'}],
#  'filters': [{'id': 'category',
#    'name': 'Categorias',
#    'type': 'text',
#    'values': [{'id': 'MLB1055',
#      'name': 'Celulares e Smartphones',
#      'path_from_root': [{'id': 'MLB1051', 'name': 'Celulares e Telefones'},
#       {'id': 'MLB1055', 'name': 'Celulares e Smartphones'}]}]},
#   {'id': 'BRAND',
#    'name': 'Marca',
#    'type': 'STRING',
#    'values': [{'id': '9344', 'name': 'Apple'}]},
#   {'id': 'LINE',
#    'name': 'Linha',
#    'type': 'STRING',
#    'values': [{'id': '58993', 'name': 'iPhone'}]}],
#  'available_filters': [{'id': 'official_store',
#    'name': 'Lojas oficiais',
#    'type': 'text',
#    'values': [{'id': 'all', 'name': 'Todas as Lojas oficiais', 'results': 646},
#     {'id': '942', 'name': 'Fast Shop', 'results': 30}]},
#   {'id': 'discount',
#    'name': 'Descontos',
#    'type': 'range',
#    'values': [{'id': '5-100', 'name': 'Mais de 5% OFF', 'results': 15},
#     {'id': '10-100', 'name': 'Mais de 10% OFF', 'results': 5},
#     {'id': '20-100', 'name': 'Mais de 20% OFF', 'results': 1}]},
#   {'id': 'state',
#    'name': 'Localização',
#    'type': 'text',
#    'values': [{'id': 'TUxCUFNBT085N2E4',
#      'name': 'São Paulo',
#      'results': 16290},
#     {'id': 'TUxCUE1JTlMxNTAyZA', 'name': 'Minas Gerais', 'results': 3972},
#     {'id': 'TUxCUFJJT08xODM5Zg', 'name': 'Rio de Janeiro', 'results': 3577},
#     {'id': 'TUxCUFBBUkExODBlZA', 'name': 'Paraná', 'results': 2104},
#     {'id': 'TUxCUFJJT0xkYzM0', 'name': 'Rio Grande do Sul', 'results': 1564},
#     {'id': 'TUxCUEJBSEFlYmEx', 'name': 'Bahia', 'results': 1476},
#     {'id': 'TUxCUFNBTkE5Nzc4', 'name': 'Santa Catarina', 'results': 1476},
#     {'id': 'TUxCUEdPSVMxNzVmMw', 'name': 'Goiás', 'results': 1120},
#     {'id': 'TUxCUERJU0wxMWJhYg', 'name': 'Distrito Federal', 'results': 956},
#     {'id': 'TUxCUENFQUExNzkyZQ', 'name': 'Ceará', 'results': 708},
#     {'id': 'TUxCUFBFUk8xZmZj', 'name': 'Pernambuco', 'results': 632},
#     {'id': 'TUxCUEVTUE8xN2Y3NA', 'name': 'Espírito Santo', 'results': 561},
#     {'id': 'TUxCUE1BVEw4ZTc', 'name': 'Mato Grosso do Sul', 'results': 408},
#     {'id': 'TUxCUE1BVE9jZDY0', 'name': 'Mato Grosso', 'results': 344},
#     {'id': 'TUxCUFBBUkFiY2Uw', 'name': 'Pará', 'results': 332},
#     {'id': 'TUxCUE1BUk81MWVi', 'name': 'Maranhão', 'results': 296},
#     {'id': 'TUxCUFBBUkE0M2I4', 'name': 'Paraíba', 'results': 236},
#     {'id': 'TUxCUEFMQVNmZjUw', 'name': 'Alagoas', 'results': 224},
#     {'id': 'TUxCUFNFUkUxMmZlOQ', 'name': 'Sergipe', 'results': 216},
#     {'id': 'TUxCUFBJQUk1NDVj', 'name': 'Piauí', 'results': 196},
#     {'id': 'TUxCUEFNQVMxNzgwYQ', 'name': 'Amazonas', 'results': 192},
#     {'id': 'TUxCUFJJT0VkMmNj', 'name': 'Rio Grande do Norte', 'results': 188},
#     {'id': 'TUxCUFJPTkExMmU4YQ', 'name': 'Rondônia', 'results': 128},
#     {'id': 'TUxCUEFNQUExNTZlNg', 'name': 'Amapá', 'results': 72},
#     {'id': 'TUxCUFRPQ1NjZDBm', 'name': 'Tocantins', 'results': 68},
#     {'id': 'TUxCUEFDUkVkNTU', 'name': 'Acre', 'results': 40},
#     {'id': 'TUxCUFJPUkExODBiMQ', 'name': 'Roraima', 'results': 32}]},
#   {'id': 'price',
#    'name': 'Preço',
#    'type': 'range',
#    'values': [{'id': '*-1000.0', 'name': 'Até R$1.000', 'results': 8203},
#     {'id': '1000.0-2500.0', 'name': 'R$1.000 a R$2.500', 'results': 16408},
#     {'id': '2500.0-*', 'name': 'Mais de R$2.500', 'results': 12933}]},
#   {'id': 'accepts_mercadopago',
#    'name': 'Filtro por MercadoPago',
#    'type': 'boolean',
#    'values': [{'id': 'yes', 'name': 'Com MercadoPago', 'results': 37544}]},
#   {'id': 'installments',
#    'name': 'Pagamento',
#    'type': 'text',
#    'values': [{'id': 'no_interest', 'name': 'Sem juros', 'results': 9728}]},
#   {'id': 'shipping',
#    'name': 'Tipo de envio',
#    'type': 'text',
#    'values': [{'id': 'mercadoenvios',
#      'name': 'Mercado Envios',
#      'results': 37524},
#     {'id': 'fulfillment', 'name': 'Full', 'results': 4}]},
#   {'id': 'power_seller',
#    'name': 'Filtro MercadoLíderes',
#    'type': 'boolean',
#    'values': [{'id': 'yes', 'name': 'Melhores vendedores', 'results': 1087}]},
#   {'id': 'since',
#    'name': 'Filtro por data de início',
#    'type': 'text',
#    'values': [{'id': 'today', 'name': 'Anunciados hoje', 'results': 804}]},
#   {'id': 'until',
#    'name': 'Filtro por data do fim',
#    'type': 'text',
#    'values': [{'id': 'today', 'name': 'Termina hoje', 'results': 292}]},
#   {'id': 'has_video',
#    'name': 'Filtro por publicações com vídeo',
#    'type': 'boolean',
#    'values': [{'id': 'yes',
#      'name': 'Publicações com vídeo',
#      'results': 1152}]},
#   {'id': 'has_pictures',
#    'name': 'Filtro por publicação com imagens',
#    'type': 'boolean',
#    'values': [{'id': 'yes', 'name': 'Com fotos', 'results': 37464}]},
#   {'id': 'shipping_cost',
#    'name': 'Custo do frete',
#    'type': 'text',
#    'values': [{'id': 'free', 'name': 'Gratis', 'results': 20201}]},
#   {'id': 'CARRIER',
#    'name': 'Operadora',
#    'type': 'STRING',
#    'values': [{'id': '298335', 'name': 'Desbloqueado', 'results': 25569},
#     {'id': '298332', 'name': 'Vivo', 'results': 411},
#     {'id': '298334', 'name': 'TIM', 'results': 270},
#     {'id': '298333', 'name': 'Claro', 'results': 237},
#     {'id': '298331', 'name': 'Oi', 'results': 129},
#     {'id': '303172', 'name': 'Nextel', 'results': 24}]},
#   {'id': 'DISPLAY_SIZE',
#    'name': 'Tamanho da tela',
#    'type': 'range',
#    'values': [{'id': '(*-5.5")', 'name': 'Menos de 5,5 "', 'results': 15084},
#     {'id': '[5.5"-5.8")', 'name': '5,5 a 5,7 "', 'results': 5382},
#     {'id': '[5.8"-6.5")', 'name': '5,8 a 6,4 "', 'results': 6009},
#     {'id': '[6.5"-*)', 'name': '6,5 " ou mais', 'results': 1434}]},
#   {'id': 'INTERNAL_MEMORY',
#    'name': 'Memória interna',
#    'type': 'range',
#    'values': [{'id': '(*-64GB)', 'name': 'Menos de 64 GB', 'results': 9774},
#     {'id': '[64GB-128GB)', 'name': '64 a 127 GB', 'results': 10164},
#     {'id': '[128GB-256GB)', 'name': '128 a 255 GB', 'results': 5127},
#     {'id': '[256GB-*)', 'name': '256 GB ou mais', 'results': 3267}]},
#   {'id': 'IS_DUAL_SIM',
#    'name': 'Outras características',
#    'type': 'boolean',
#    'values': [{'id': '242085', 'name': 'É Dual SIM', 'results': 732}]},
#   {'id': 'IS_WATER_RESISTANT',
#    'name': 'Outras características',
#    'type': 'boolean',
#    'values': [{'id': '242085',
#      'name': 'É resistente à água',
#      'results': 19521}]},
#   {'id': 'ITEM_CONDITION',
#    'name': 'Condição',
#    'type': 'STRING',
#    'values': [{'id': '2230581', 'name': 'Usado', 'results': 24243},
#     {'id': '2230284', 'name': 'Novo', 'results': 3411},
#     {'id': '2230582', 'name': 'Recondicionado', 'results': 705}]},
#   {'id': 'MAIN_COLOR',
#    'name': 'Cor principal',
#    'type': 'list',
#    'values': [{'id': '2450294', 'name': 'Cinza', 'results': 7716},
#     {'id': '2450295', 'name': 'Preto', 'results': 4836},
#     {'id': '2450289', 'name': 'Dourado', 'results': 3621},
#     {'id': '2450312', 'name': 'Rosa', 'results': 2562},
#     {'id': '2450308', 'name': 'Branco', 'results': 1332},
#     {'id': '2450307', 'name': 'Vermelho', 'results': 1032},
#     {'id': '2450293', 'name': 'Azul', 'results': 399},
#     {'id': '2450314', 'name': 'Verde', 'results': 333},
#     {'id': '2450303', 'name': 'Prateado', 'results': 108},
#     {'id': '2450296', 'name': 'Amarelo', 'results': 78},
#     {'id': '2450311', 'name': 'Violeta', 'results': 48},
#     {'id': '2450299', 'name': 'Cinza-escuro', 'results': 33},
#     {'id': '2450280', 'name': 'Rosa-claro', 'results': 27},
#     {'id': '2450313', 'name': 'Coral-claro', 'results': 9},
#     {'id': '2450309', 'name': 'Dourado-escuro', 'results': 9}]},
#   {'id': 'MAIN_FRONT_CAMERA_RESOLUTION',
#    'name': 'Resolução da câmera frontal principal',
#    'type': 'range',
#    'values': [{'id': '(*-7Mpx)', 'name': '7 Mpx ou menos', 'results': 8256},
#     {'id': '[7Mpx-12Mpx)', 'name': '7 a 11 Mpx', 'results': 16413},
#     {'id': '[12Mpx-*)', 'name': '12 Mpx ou mais', 'results': 2937}]},
#   {'id': 'MOBILE_NETWORK',
#    'name': 'Rede',
#    'type': 'STRING',
#    'values': [{'id': '367876', 'name': '4G/LTE', 'results': 24138},
#     {'id': '7472027', 'name': '5G', 'results': 1062},
#     {'id': '367874', 'name': '3G', 'results': 471},
#     {'id': '7472026', 'name': '2G', 'results': 273}]},
#   {'id': 'MODEL',
#    'name': 'Modelo',
#    'type': 'STRING',
#    'values': [{'id': '312155', 'name': 'iPhone 7', 'results': 4401},
#     {'id': '2244670', 'name': 'iPhone 8', 'results': 2619},
#     {'id': '312151', 'name': 'iPhone 6s', 'results': 2592},
#     {'id': '2244673', 'name': 'iPhone 8 Plus', 'results': 2280},
#     {'id': '312157', 'name': 'iPhone 7 Plus', 'results': 2208},
#     {'id': '5414260', 'name': 'iPhone XR', 'results': 1572},
#     {'id': '1164456', 'name': 'iPhone X', 'results': 1536},
#     {'id': '312149', 'name': 'iPhone 6', 'results': 1530},
#     {'id': '312144', 'name': 'iPhone 5s', 'results': 1245},
#     {'id': '7739079', 'name': 'iPhone 11', 'results': 1032},
#     {'id': '312154', 'name': 'iPhone SE', 'results': 648},
#     {'id': '5414168', 'name': 'iPhone XS Max', 'results': 576},
#     {'id': '7741677', 'name': 'iPhone 11 Pro Max', 'results': 492},
#     {'id': '312145', 'name': 'iPhone 4s', 'results': 471},
#     {'id': '312153', 'name': 'iPhone 6s Plus', 'results': 417},
#     {'id': '5414079', 'name': 'iPhone XS', 'results': 402},
#     {'id': '312152', 'name': 'iPhone 5', 'results': 402},
#     {'id': '9081382', 'name': 'iPhone 12', 'results': 396},
#     {'id': '312150', 'name': 'iPhone 6 Plus', 'results': 369},
#     {'id': '9081385', 'name': 'iPhone 12 Pro Max', 'results': 357},
#     {'id': '14608', 'name': 'iPhone', 'results': 339},
#     {'id': '7741023', 'name': 'iPhone 11 Pro', 'results': 336},
#     {'id': '312143', 'name': 'iPhone 5c', 'results': 285},
#     {'id': '14610', 'name': 'iPhone 4', 'results': 279},
#     {'id': '9081384', 'name': 'iPhone 12 Pro', 'results': 168},
#     {'id': '5414092', 'name': 'iPhone XS Dual SIM', 'results': 153},
#     {'id': '9081383', 'name': 'iPhone 12 mini', 'results': 132},
#     {'id': '8230322', 'name': 'iPhone SE (2nd Generation)', 'results': 111},
#     {'id': '9676776', 'name': '6s', 'results': 105},
#     {'id': '27251', 'name': '7', 'results': 57},
#     {'id': '14609', 'name': 'iPhone 3GS', 'results': 51},
#     {'id': '52828', 'name': '7 Plus', 'results': 42},
#     {'id': '14605', 'name': 'iPhone 3G', 'results': 39},
#     {'id': '58615', 'name': '5', 'results': 18},
#     {'id': '58054', 'name': 'XR', 'results': 12},
#     {'id': '59833', 'name': '6', 'results': 9},
#     {'id': '11043', 'name': '8', 'results': 9}]},
#   {'id': 'OPERATING_SYSTEM_NAME',
#    'name': 'Nome do sistema operacional',
#    'type': 'STRING',
#    'values': [{'id': '7404961', 'name': 'iOS', 'results': 28032}]},
#   {'id': 'RAM',
#    'name': 'Memória RAM',
#    'type': 'range',
#    'values': [{'id': '(*-2GB]', 'name': '2 GB ou menos', 'results': 13590},
#     {'id': '[3GB-3GB]', 'name': '3 GB', 'results': 7104},
#     {'id': '[4GB-4GB]', 'name': '4 GB', 'results': 3627},
#     {'id': '[5GB-5GB]', 'name': '5 GB', 'results': 120},
#     {'id': '[6GB-6GB]', 'name': '6 GB', 'results': 621},
#     {'id': '[7GB-7GB]', 'name': '7 GB', 'results': 9},
#     {'id': '[8GB-*)', 'name': '8 GB ou mais', 'results': 1869}]},
#   {'id': 'SHIPPING_ORIGIN',
#    'name': 'Tipo de compra',
#    'type': 'STRING',
#    'values': [{'id': '10215068', 'name': 'Local', 'results': 28383}]},
#   {'id': 'WITH_FACIAL_RECOGNITION',
#    'name': 'Outras características',
#    'type': 'boolean',
#    'values': [{'id': '242085',
#      'name': 'Com reconhecimento facial',
#      'results': 7614}]},
#   {'id': 'WITH_FAST_CHARGING',
#    'name': 'Outras características',
#    'type': 'boolean',
#    'values': [{'id': '242085',
#      'name': 'Com carregamento rápido',
#      'results': 9483}]},
#   {'id': 'WITH_FINGERPRINT_READER',
#    'name': 'Outras características',
#    'type': 'boolean',
#    'values': [{'id': '242085',
#      'name': 'Com leitor de impressão digital',
#      'results': 18729}]},
#   {'id': 'WITH_NFC',
#    'name': 'Outras características',
#    'type': 'boolean',
#    'values': [{'id': '242085', 'name': 'Com NFC', 'results': 22635}]}]}

# %%
temp.keys()
# Out:
# dict_keys(['site_id', 'query', 'paging', 'results', 'secondary_results', 'related_results', 'sort', 'available_sorts', 'filters', 'available_filters'])

# %%
for anuncio in temp['results']:
    print(anuncio['title'])
# Out:
# Apple iPhone 11 (128 Gb) - Branco
# Apple iPhone 11 (64 Gb) - Preto
#  iPhone 7 32 Gb Ouro Rosa
#  iPhone XR 64 Gb Branco
#  iPhone 8 Plus 64 Gb Prateado
# Apple iPhone 12 Pro Max (128 Gb) - Prateado
#  iPhone 8 64 Gb Cinza-espacial
# Apple iPhone 12 (64 Gb) - Branco
# Apple iPhone 12 Pro Max (256 Gb) - Grafite
# Apple iPhone 12 (128 Gb) - Preto
#  iPhone XR 128 Gb Branco
#  iPhone 7 128 Gb Dourado
# iPhone 7 Plus 32 Gb Prateado
#  iPhone 6s 128 Gb Cinza-espacial
# Apple iPhone 12 Pro (128 Gb) - Dourado
# Apple iPhone 11 (256 Gb) - Branco
#  iPhone 6s 64 Gb Cinza-espacial
#  iPhone 6s 32 Gb Ouro Rosa
# iPhone 7 Plus 128 Gb Ouro Rosa
# Apple iPhone 12 Pro Max (512 Gb) - Azul-pacífico
#  iPhone X 256 Gb Prateado
#  iPhone X 64 Gb Prateado
#  iPhone 8 128 Gb Dourado
# Apple iPhone 12 Mini (64 Gb) - Azul
# Apple iPhone 12 Pro (256 Gb) - Azul-pacífico
# iPhone 11 Pro Max 256 Gb Verde-meia-noite
# iPhone 11 Pro 64 Gb Cinza-espacial
#  iPhone 8 Plus 256 Gb (product)red
#  iPhone SE (2nd Generation) 64 Gb Branco
#  iPhone XS 64 Gb Dourado
# iPhone 11 Pro Max 64 Gb Verde-meia-noite
# Apple iPhone 12 (256 Gb) - Azul
# iPhone 11 Pro 256 Gb Verde-meia-noite
# Apple iPhone 12 Mini (128 Gb) - (product)red
#  iPhone 7 256 Gb Preto-fosco
#  iPhone 6s Plus 32 Gb Cinza-espacial
#  iPhone 8 256 Gb Dourado
#  iPhone 6 16 Gb Cinza-espacial
# Apple iPhone 12 Pro (512 Gb) - Dourado
#  iPhone 5s 16 Gb Cinza-espacial
#  iPhone 6 Plus 128 Gb Dourado
# Apple iPhone X 64 Gb 5k Original Pronta Entrega - Vitrine
# iPhone X Vitrine 256gb Original Appl Exposição 12x  S/ Juros
# Apple iPhone 4s 8gb Desbloqueado Original Anatel - Exposição
# iPhone 8 64gb Apple Exposicao Garantia 12x Sem Juros
# Apple iPhone 8 Plus 64gb Original Vitrine Desbloqueado 12x
# iPhone 6s 128gb Apple Exposicao Garantia 12x Sem Juros
#  iPhone 8 Plus 64gb Original De Exposição Em  12x Sem Juros
# Apple iPhone 4s 16gb Desbloqueado Original Anatel Exposição
# iPhone 8 64gb Vitrine Apple Tela 4,7  Em 12x Sem Juros

# %% [markdown]
# ***Transformando o resultado da API em um dataframe***

# %%
df = pd.DataFrame(temp['results'])
df.head()
# Out:
#               id site_id                              title  \
# 0  MLB1729453817     MLB  Apple iPhone 11 (128 Gb) - Branco
# 1  MLB1929087758     MLB    Apple iPhone 11 (64 Gb) - Preto
# 2  MLB1859295006     MLB           iPhone 7 32 Gb Ouro Rosa
# 3  MLB1924083629     MLB             iPhone XR 64 Gb Branco
# 4  MLB1857350525     MLB       iPhone 8 Plus 64 Gb Prateado
#
#                                               seller   price  \
# 0  {'id': 234000251, 'permalink': 'http://perfil....  4454.0
# 1  {'id': 53046290, 'permalink': 'http://perfil.m...  4439.0
# 2  {'id': 577525755, 'permalink': 'http://perfil....  1525.0
# 3  {'id': 36583886, 'permalink': 'http://perfil.m...  3642.0
# 4  {'id': 418784891, 'permalink': 'http://perfil....  2822.0
#
#                                               prices sale_price currency_id  \
# 0  {'id': 'MLB1729453817', 'prices': [{'id': '55'...       None         BRL
# 1  {'id': 'MLB1929087758', 'prices': [{'id': '2',...       None         BRL
# 2  {'id': 'MLB1859295006', 'prices': [{'id': '9',...       None         BRL
# 3  {'id': 'MLB1924083629', 'prices': [{'id': '3',...       None         BRL
# 4  {'id': 'MLB1857350525', 'prices': [{'id': '11'...       None         BRL
#
#    available_quantity  sold_quantity  ... differential_pricing original_price  \
# 0                 882           1713  ...     {'id': 33580182}         5599.0
# 1                   1              0  ...     {'id': 33580182}            NaN
# 2                   1              2  ...     {'id': 33580182}            NaN
# 3                   1             12  ...     {'id': 33580182}            NaN
# 4                  12             29  ...     {'id': 33580182}            NaN
#
#   category_id official_store_id       domain_id catalog_product_id  \
# 0     MLB1055             942.0  MLB-CELLPHONES        MLB15149568
# 1     MLB1055               NaN  MLB-CELLPHONES        MLB15149561
# 2     MLB1055               NaN  MLB-CELLPHONES         MLB6240113
# 3     MLB1055               NaN  MLB-CELLPHONES        MLB12866679
# 4     MLB1055               NaN  MLB-CELLPHONES         MLB8752452
#
#                                                 tags  catalog_listing  \
# 0  [deal_of_the_day, good_quality_picture, good_q...             True
# 1  [extended_warranty_eligible, immediate_payment...             True
# 2  [loyalty_discount_eligible, extended_warranty_...             True
# 3  [extended_warranty_eligible, good_quality_pict...             True
# 4  [catalog_boost, extended_warranty_eligible, go...             True
#
#   use_thumbnail_id order_backend
# 0             True             1
# 1             True             2
# 2             True             3
# 3             True             4
# 4             True             5
#
# [5 rows x 33 columns]

# %%
df.head(1).T
# Out:
#                                                                       0
# id                                                        MLB1729453817
# site_id                                                             MLB
# title                                 Apple iPhone 11 (128 Gb) - Branco
# seller                {'id': 234000251, 'permalink': 'http://perfil....
# price                                                              4454
# prices                {'id': 'MLB1729453817', 'prices': [{'id': '55'...
# sale_price                                                         None
# currency_id                                                         BRL
# available_quantity                                                  882
# sold_quantity                                                      1713
# buying_mode                                                  buy_it_now
# listing_type_id                                                gold_pro
# stop_time                                      2040-11-22T04:00:00.000Z
# condition                                                           new
# permalink             https://www.mercadolivre.com.br/apple-iphone-1...
# thumbnail             http://http2.mlstatic.com/D_821379-MLA46114620...
# thumbnail_id                               821379-MLA46114620180_052021
# accepts_mercadopago                                                True
# installments          {'quantity': 12, 'amount': 371.17, 'rate': 0, ...
# address               {'state_id': 'BR-SP', 'state_name': 'São Paulo...
# shipping              {'free_shipping': False, 'mode': 'me1', 'tags'...
# seller_address        {'id': '', 'comment': '', 'address_line': '', ...
# attributes            [{'values': [{'id': '9344', 'name': 'Apple', '...
# differential_pricing                                   {'id': 33580182}
# original_price                                                     5599
# category_id                                                     MLB1055
# official_store_id                                                   942
# domain_id                                                MLB-CELLPHONES
# catalog_product_id                                          MLB15149568
# tags                  [deal_of_the_day, good_quality_picture, good_q...
# catalog_listing                                                    True
# use_thumbnail_id                                                   True
# order_backend                                                         1

# %%
df.address.apply(pd.Series).head()
# Out:
#   state_id state_name             city_id  city_name
# 0    BR-SP  São Paulo    QlItU1BDYWphbWFy    Cajamar
# 1    BR-SP  São Paulo            BR-SP-44  São Paulo
# 2    BR-SP  São Paulo  QlItU1BDYXBpdmFyaQ   Capivari
# 3    BR-SP  São Paulo            BR-SP-31     Osasco
# 4    BR-PR     Paraná    TUxCQ0NVUjYyZmY1   Curitiba

# %%
df2 = df.merge(df.address.apply(pd.Series),left_index=True, right_index=True).drop('address', axis=1)

# %%
df2.head(1).T
# Out:
#                                                                       0
# id                                                        MLB1729453817
# site_id                                                             MLB
# title                                 Apple iPhone 11 (128 Gb) - Branco
# seller                {'id': 234000251, 'permalink': 'http://perfil....
# price                                                              4454
# prices                {'id': 'MLB1729453817', 'prices': [{'id': '55'...
# sale_price                                                         None
# currency_id                                                         BRL
# available_quantity                                                  882
# sold_quantity                                                      1713
# buying_mode                                                  buy_it_now
# listing_type_id                                                gold_pro
# stop_time                                      2040-11-22T04:00:00.000Z
# condition                                                           new
# permalink             https://www.mercadolivre.com.br/apple-iphone-1...
# thumbnail             http://http2.mlstatic.com/D_821379-MLA46114620...
# thumbnail_id                               821379-MLA46114620180_052021
# accepts_mercadopago                                                True
# installments          {'quantity': 12, 'amount': 371.17, 'rate': 0, ...
# shipping              {'free_shipping': False, 'mode': 'me1', 'tags'...
# seller_address        {'id': '', 'comment': '', 'address_line': '', ...
# attributes            [{'values': [{'id': '9344', 'name': 'Apple', '...
# differential_pricing                                   {'id': 33580182}
# original_price                                                     5599
# category_id                                                     MLB1055
# official_store_id                                                   942
# domain_id                                                MLB-CELLPHONES
# catalog_product_id                                          MLB15149568
# tags                  [deal_of_the_day, good_quality_picture, good_q...
# catalog_listing                                                    True
# use_thumbnail_id                                                   True
# order_backend                                                         1
# state_id                                                          BR-SP
# state_name                                                    São Paulo
# city_id                                                QlItU1BDYWphbWFy
# city_name                                                       Cajamar

# %%
df2.columns
# Out:
# Index(['id', 'site_id', 'title', 'seller', 'price', 'prices', 'sale_price',
#        'currency_id', 'available_quantity', 'sold_quantity', 'buying_mode',
#        'listing_type_id', 'stop_time', 'condition', 'permalink', 'thumbnail',
#        'thumbnail_id', 'accepts_mercadopago', 'installments', 'shipping',
#        'seller_address', 'attributes', 'differential_pricing',
#        'original_price', 'category_id', 'official_store_id', 'domain_id',
#        'catalog_product_id', 'tags', 'catalog_listing', 'use_thumbnail_id',
#        'order_backend', 'state_id', 'state_name', 'city_id', 'city_name'],
#       dtype='object')

# %%
print('Contagem:', df2.loc[df2.state_name=='Minas Gerais',:].price.count())
print('Média:', round(df2.loc[df2.state_name=='Minas Gerais',:].price.mean(),2))
# Out:
# Contagem: 5
# Média: 4415.2
